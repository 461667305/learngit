# %%
# -*- coding:utf-8 -*-
#Python 3.6.3
from WindPy import *
import pandas as pd
import datetime
import math
import numpy as np
import xlrd

# %%
w.start();
##getting data
statement_2016=w.wss("A.N,AAL.O,AAP.N,AAPL.O,ABBV.N,ABC.N,ABT.N,ACN.N,ADBE.O,ADI.O,ADM.N,ADP.O,ADS.N,ADSK.O,AEE.N,AEP.N,AES.N,AET.N,AFL.N,AGN.N,AIG.N,AIV.N,AIZ.N,AJG.N,AKAM.O,ALB.N,ALGN.O,ALK.N,ALL.N,ALLE.N,ALXN.O,AMAT.O,AMD.O,AME.N,AMG.N,AMGN.O,AMP.N,AMT.N,AMZN.O,ANDV.N,ANSS.O,ANTM.N,AON.N,AOS.N,APA.N,APC.N,APD.N,APH.N,APTV.N,ARE.N,ARNC.N,ATVI.O,AVB.N,AVGO.O,AVY.N,AWK.N,AXP.N,AYI.N,AZO.N,BA.N,BAC.N,BAX.N,BBT.N,BBY.N,BDX.N,BEN.N,BF_B.N,BHF.O,BHGE.N,BIIB.O,BK.N,BLK.N,BLL.N,BMY.N,BRK_B.N,BSX.N,BWA.N,BXP.N,C.N,CA.O,CAG.N,CAH.N,CAT.N,CB.N,CBG.N,CBOE.O,CBS.N,CCI.N,CCL.N,CDNS.O,CELG.O,CERN.O,CF.N,CFG.N,CHD.N,CHK.N,CHRW.O,CHTR.O,CI.N,CINF.O,CL.N,CLX.N,CMA.N,CMCSA.O,CME.O,CMG.N,CMI.N,CMS.N,CNC.N,CNP.N,COF.N,COG.N,COL.N,COO.N,COP.N,COST.O,COTY.N,CPB.N,CRM.N,CSCO.O,CSRA.N,CSX.O,CTAS.O,CTL.N,CTSH.O,CTXS.O,CVS.N,CVX.N,CXO.N,D.N,DAL.N,DE.N,DFS.N,DG.N,DGX.N,DHI.N,DHR.N,DIS.N,DISCA.O,DISCK.O,DISH.O,DLR.N,DLTR.O,DOV.N,DPS.N,DRE.N,DRI.N,DTE.N,DUK.N,DVA.N,DVN.N,DWDP.N,DXC.N,EA.O,EBAY.O,ECL.N,ED.N,EFX.N,EIX.N,EL.N,EMN.N,EMR.N,EOG.N,EQIX.O,EQR.N,EQT.N,ES.N,ESRX.O,ESS.N,ETFC.O,ETN.N,ETR.N,EVHC.N,EW.N,EXC.N,EXPD.O,EXPE.O,EXR.N,F.N,FAST.O,FB.O,FBHS.N,FCX.N,FDX.N,FE.N,FFIV.O,FIS.N,FISV.O,FITB.O,FL.N,FLIR.O,FLR.N,FLS.N,FMC.N,FOX.O,FOXA.O,FRT.N,FTI.N,FTV.N,GD.N,GE.N,GGP.N,GILD.O,GIS.N,GLW.N,GM.N,GOOG.O,GOOGL.O,GPC.N,GPN.N,GPS.N,GRMN.O,GS.N,GT.O,GWW.N,HAL.N,HAS.O,HBAN.O,HBI.N,HCA.N,HCN.N,HCP.N,HD.N,HES.N,HIG.N,HII.N,HLT.N,HOG.N,HOLX.O,HON.N,HP.N,HPE.N,HPQ.N,HRB.N,HRL.N,HRS.N,HSIC.O,HST.N,HSY.N,HUM.N,IBM.N,ICE.N,IDXX.O,IFF.N,ILMN.O,INCY.O,INFO.O,INTC.O,INTU.O,IP.N,IPG.N,IQV.N,IR.N,IRM.N,ISRG.O,IT.N,ITW.N,IVZ.N,JBHT.O,JCI.N,JEC.N,JNJ.N,JNPR.N,JPM.N,JWN.N,K.N,KEY.N,KHC.O,KIM.N,KLAC.O,KMB.N,KMI.N,KMX.N,KO.N,KORS.N,KR.N,KSS.N,KSU.N,L.N,LB.N,LEG.N,LEN.N,LH.N,LKQ.O,LLL.N,LLY.N,LMT.N,LNC.N,LNT.N,LOW.N,LRCX.O,LUK.N,LUV.N,LYB.N,M.N,MA.N,MAA.N,MAC.N,MAR.O,MAS.N,MAT.O,MCD.N,MCHP.O,MCK.N,MCO.N,MDLZ.O,MDT.N,MET.N,MGM.N,MHK.N,MKC.N,MLM.N,MMC.N,MMM.N,MNST.O,MO.N,MON.N,MOS.N,MPC.N,MRK.N,MRO.N,MS.N,MSFT.O,MSI.N,MTB.N,MTD.N,MU.O,MYL.O,NAVI.O,NBL.N,NCLH.N,NDAQ.O,NEE.N,NEM.N,NFLX.O,NFX.N,NI.N,NKE.N,NLSN.N,NOC.N,NOV.N,NRG.N,NSC.N,NTAP.O,NTRS.O,NUE.N,NVDA.O,NWL.N,NWS.O,NWSA.O,O.N,OKE.N,OMC.N,ORCL.N,ORLY.O,OXY.N,PAYX.O,PBCT.O,PCAR.O,PCG.N,PCLN.O,PDCO.O,PEG.N,PEP.O,PFE.N,PFG.O,PG.N,PGR.N,PH.N,PHM.N,PKG.N,PKI.N,PLD.N,PM.N,PNC.N,PNR.N,PNW.N,PPG.N,PPL.N,PRGO.N,PRU.N,PSA.N,PSX.N,PVH.N,PWR.N,PX.N,PXD.N,PYPL.O,QCOM.O,QRVO.O,RCL.N,RE.N,REG.N,REGN.O,RF.N,RHI.N,RHT.N,RJF.N,RL.N,RMD.N,ROK.N,ROP.N,ROST.O,RRC.N,RSG.N,RTN.N,SBAC.O,SBUX.O,SCG.N,SCHW.N,SEE.N,SHW.N,SIG.N,SJM.N,SLB.N,SLG.N,SNA.N,SNI.O,SNPS.O,SO.N,SPG.N,SPGI.N,SRCL.O,SRE.N,STI.N,STT.N,STX.O,STZ.N,SWK.N,SWKS.O,SYF.N,SYK.N,SYMC.O,SYY.N,T.N,TAP.N,TDG.N,TEL.N,TGT.N,TIF.N,TJX.N,TMK.N,TMO.N,TPR.N,TRIP.O,TROW.O,TRV.N,TSCO.O,TSN.N,TSS.N,TWX.N,TXN.O,TXT.N,UA.N,UAA.N,UAL.N,UDR.N,UHS.N,ULTA.O,UNH.N,UNM.N,UNP.N,UPS.N,URI.N,USB.N,UTX.N,V.N,VAR.N,VFC.N,VIAB.O,VLO.N,VMC.N,VNO.N,VRSK.O,VRSN.O,VRTX.O,VTR.N,VZ.N,WAT.N,WBA.O,WDC.O,WEC.N,WFC.N,WHR.N,WLTW.O,WM.N,WMB.N,WMT.N,WRK.N,WU.N,WY.N,WYN.N,WYNN.O,XEC.N,XEL.O,XL.N,XLNX.O,XOM.N,XRAY.O,XRX.N,XYL.N,YUM.N,ZBH.N,ZION.O,ZTS.N", "wgsd_cce,wgsd_invest_trading,wgsd_invest_st_oth,wgsd_receiv_tot,wgsd_inventories,wgsd_assets_curr_oth,wgsd_assets_curr,wgsd_ppe_net,wgsd_invest_eq,wgsd_invest_htm,wgsd_invest_afs,wgsd_invest_lt_oth,wgsd_gw_intang_,wgsd_land_use_rights,wgsd_assets_lt_oth,wgsd_assets_lt,wgsd_lend_ib,wgsd_sec_colla,wgsd_loans_net,wgsd_loans_hfs,wgsd_assets_oth,wgsd_invest_oth,wgsd_receiv_insur,wgsd_def_plcy_acq_costs,wgsd_receiv_reinsur,wgsd_receiv_net,wgsd_receiv_st_oth,wgsd_loans_mtg_net,wgsd_real_estate_net,wgsd_ppe_net_oth,wgsd_assets,wgsd_pay_acct,wgsd_pay_tax,wgsd_liabs_trading,wgsd_debt_st,wgsd_liabs_curr_oth,wgsd_liabs_curr,wgsd_debt_lt,wgsd_liabs_lt_oth,wgsd_liabs_lt,wgsd_deposits,wgsd_borrow_ib,wgsd_fin_colla,wgsd_liabs_oth,wgsd_liabs_insur_contract,wgsd_pay_reinsur,wgsd_liabs_invest_contract,wgsd_liabs,wgsd_pfd_stk,wgsd_com_eq_par,wgsd_rsv,wgsd_apic,wgsd_com_eq_retain_earn,wgsd_rsv_other,wgsd_treas_stk,wgsd_com_eq_for_exch,wgsd_com_eq_paholder,wgsd_com_eq,wgsd_min_int,wgsd_stkhldrs_eq,wgsd_liabs_stkhldrs_eq,wgsd_sales_oper,wgsd_sales_oth,wgsd_sales,wgsd_int_inc_net,wgsd_int_inc,wgsd_fee_comm_inc_net,wgsd_fee_comm_inc,wgsd_trade_inc_net,wgsd_premiums_earned,wgsd_rev_rent,wgsd_tenant_reim_exp,wgsd_gain_sale_real_estate,wgsd_mtg_inc,wgsd_oper_cost,wgsd_oper_exp,wgsd_sga_exp,wgsd_rd_exp,wgsd_oper_exp_tot,wgsd_ebit_oper,wgsd_int_exp,wgsd_prov_loan_loss,wgsd_fee_comm_exp,wgsd_invest_gain,wgsd_no_oper_inc,wgsd_ebt_excl_unusual_items,wgsd_unusual_items,wgsd_inc_pretax,wgsd_inc_tax,wgsd_min_int_exp,wgsd_continue_oper,wgsd_disc_oper,wgsd_exod,wgsd_net_inc,wgsd_dvd_pfd_adj,wgsd_net_inc_dil,wgsd_compr_inc,is_sharepayments,is_ebitda_ard,wgsd_net_inc_cf,wgsd_dep_exp_cf,wgsd_wkcap_chg,wgsd_non_cash_chg,wgsd_oper_cf,wgsd_capex_ff,wgsd_assets_bus_cf,wgsd_invest_purch_cf,wgsd_invest_sale_cf,wgsd_invest_oth_cf,wgsd_invest_cf,wgsd_debt_iss_cf,wgsd_debt_reduct_cf,wgsd_stk_purch_cf,wgsd_stk_sale_cf,wgsd_div_cf,wgsd_fin_oth_cf,wgsd_fin_cf,wgsd_chg_cash_cf,wgsd_cash_beg_bal_cf,wgsd_cash_end_bal_cf,wgsd_for_exch_cf,wgsd_cash_bal_chg_cf,wgsd_turndays,wgsd_invturndays,wgsd_arturndays,wgsd_arturn,wgsd_invturn,wgsd_caturn,wgsd_faturn,wgsd_assetsturn,total_shares","unit=1;rptDate=20161231;rptType=1;currencyType=")
statement_2015=w.wss("A.N,AAL.O,AAP.N,AAPL.O,ABBV.N,ABC.N,ABT.N,ACN.N,ADBE.O,ADI.O,ADM.N,ADP.O,ADS.N,ADSK.O,AEE.N,AEP.N,AES.N,AET.N,AFL.N,AGN.N,AIG.N,AIV.N,AIZ.N,AJG.N,AKAM.O,ALB.N,ALGN.O,ALK.N,ALL.N,ALLE.N,ALXN.O,AMAT.O,AMD.O,AME.N,AMG.N,AMGN.O,AMP.N,AMT.N,AMZN.O,ANDV.N,ANSS.O,ANTM.N,AON.N,AOS.N,APA.N,APC.N,APD.N,APH.N,APTV.N,ARE.N,ARNC.N,ATVI.O,AVB.N,AVGO.O,AVY.N,AWK.N,AXP.N,AYI.N,AZO.N,BA.N,BAC.N,BAX.N,BBT.N,BBY.N,BDX.N,BEN.N,BF_B.N,BHF.O,BHGE.N,BIIB.O,BK.N,BLK.N,BLL.N,BMY.N,BRK_B.N,BSX.N,BWA.N,BXP.N,C.N,CA.O,CAG.N,CAH.N,CAT.N,CB.N,CBG.N,CBOE.O,CBS.N,CCI.N,CCL.N,CDNS.O,CELG.O,CERN.O,CF.N,CFG.N,CHD.N,CHK.N,CHRW.O,CHTR.O,CI.N,CINF.O,CL.N,CLX.N,CMA.N,CMCSA.O,CME.O,CMG.N,CMI.N,CMS.N,CNC.N,CNP.N,COF.N,COG.N,COL.N,COO.N,COP.N,COST.O,COTY.N,CPB.N,CRM.N,CSCO.O,CSRA.N,CSX.O,CTAS.O,CTL.N,CTSH.O,CTXS.O,CVS.N,CVX.N,CXO.N,D.N,DAL.N,DE.N,DFS.N,DG.N,DGX.N,DHI.N,DHR.N,DIS.N,DISCA.O,DISCK.O,DISH.O,DLR.N,DLTR.O,DOV.N,DPS.N,DRE.N,DRI.N,DTE.N,DUK.N,DVA.N,DVN.N,DWDP.N,DXC.N,EA.O,EBAY.O,ECL.N,ED.N,EFX.N,EIX.N,EL.N,EMN.N,EMR.N,EOG.N,EQIX.O,EQR.N,EQT.N,ES.N,ESRX.O,ESS.N,ETFC.O,ETN.N,ETR.N,EVHC.N,EW.N,EXC.N,EXPD.O,EXPE.O,EXR.N,F.N,FAST.O,FB.O,FBHS.N,FCX.N,FDX.N,FE.N,FFIV.O,FIS.N,FISV.O,FITB.O,FL.N,FLIR.O,FLR.N,FLS.N,FMC.N,FOX.O,FOXA.O,FRT.N,FTI.N,FTV.N,GD.N,GE.N,GGP.N,GILD.O,GIS.N,GLW.N,GM.N,GOOG.O,GOOGL.O,GPC.N,GPN.N,GPS.N,GRMN.O,GS.N,GT.O,GWW.N,HAL.N,HAS.O,HBAN.O,HBI.N,HCA.N,HCN.N,HCP.N,HD.N,HES.N,HIG.N,HII.N,HLT.N,HOG.N,HOLX.O,HON.N,HP.N,HPE.N,HPQ.N,HRB.N,HRL.N,HRS.N,HSIC.O,HST.N,HSY.N,HUM.N,IBM.N,ICE.N,IDXX.O,IFF.N,ILMN.O,INCY.O,INFO.O,INTC.O,INTU.O,IP.N,IPG.N,IQV.N,IR.N,IRM.N,ISRG.O,IT.N,ITW.N,IVZ.N,JBHT.O,JCI.N,JEC.N,JNJ.N,JNPR.N,JPM.N,JWN.N,K.N,KEY.N,KHC.O,KIM.N,KLAC.O,KMB.N,KMI.N,KMX.N,KO.N,KORS.N,KR.N,KSS.N,KSU.N,L.N,LB.N,LEG.N,LEN.N,LH.N,LKQ.O,LLL.N,LLY.N,LMT.N,LNC.N,LNT.N,LOW.N,LRCX.O,LUK.N,LUV.N,LYB.N,M.N,MA.N,MAA.N,MAC.N,MAR.O,MAS.N,MAT.O,MCD.N,MCHP.O,MCK.N,MCO.N,MDLZ.O,MDT.N,MET.N,MGM.N,MHK.N,MKC.N,MLM.N,MMC.N,MMM.N,MNST.O,MO.N,MON.N,MOS.N,MPC.N,MRK.N,MRO.N,MS.N,MSFT.O,MSI.N,MTB.N,MTD.N,MU.O,MYL.O,NAVI.O,NBL.N,NCLH.N,NDAQ.O,NEE.N,NEM.N,NFLX.O,NFX.N,NI.N,NKE.N,NLSN.N,NOC.N,NOV.N,NRG.N,NSC.N,NTAP.O,NTRS.O,NUE.N,NVDA.O,NWL.N,NWS.O,NWSA.O,O.N,OKE.N,OMC.N,ORCL.N,ORLY.O,OXY.N,PAYX.O,PBCT.O,PCAR.O,PCG.N,PCLN.O,PDCO.O,PEG.N,PEP.O,PFE.N,PFG.O,PG.N,PGR.N,PH.N,PHM.N,PKG.N,PKI.N,PLD.N,PM.N,PNC.N,PNR.N,PNW.N,PPG.N,PPL.N,PRGO.N,PRU.N,PSA.N,PSX.N,PVH.N,PWR.N,PX.N,PXD.N,PYPL.O,QCOM.O,QRVO.O,RCL.N,RE.N,REG.N,REGN.O,RF.N,RHI.N,RHT.N,RJF.N,RL.N,RMD.N,ROK.N,ROP.N,ROST.O,RRC.N,RSG.N,RTN.N,SBAC.O,SBUX.O,SCG.N,SCHW.N,SEE.N,SHW.N,SIG.N,SJM.N,SLB.N,SLG.N,SNA.N,SNI.O,SNPS.O,SO.N,SPG.N,SPGI.N,SRCL.O,SRE.N,STI.N,STT.N,STX.O,STZ.N,SWK.N,SWKS.O,SYF.N,SYK.N,SYMC.O,SYY.N,T.N,TAP.N,TDG.N,TEL.N,TGT.N,TIF.N,TJX.N,TMK.N,TMO.N,TPR.N,TRIP.O,TROW.O,TRV.N,TSCO.O,TSN.N,TSS.N,TWX.N,TXN.O,TXT.N,UA.N,UAA.N,UAL.N,UDR.N,UHS.N,ULTA.O,UNH.N,UNM.N,UNP.N,UPS.N,URI.N,USB.N,UTX.N,V.N,VAR.N,VFC.N,VIAB.O,VLO.N,VMC.N,VNO.N,VRSK.O,VRSN.O,VRTX.O,VTR.N,VZ.N,WAT.N,WBA.O,WDC.O,WEC.N,WFC.N,WHR.N,WLTW.O,WM.N,WMB.N,WMT.N,WRK.N,WU.N,WY.N,WYN.N,WYNN.O,XEC.N,XEL.O,XL.N,XLNX.O,XOM.N,XRAY.O,XRX.N,XYL.N,YUM.N,ZBH.N,ZION.O,ZTS.N", "wgsd_cce,wgsd_invest_trading,wgsd_invest_st_oth,wgsd_receiv_tot,wgsd_inventories,wgsd_assets_curr_oth,wgsd_assets_curr,wgsd_ppe_net,wgsd_invest_eq,wgsd_invest_htm,wgsd_invest_afs,wgsd_invest_lt_oth,wgsd_gw_intang_,wgsd_land_use_rights,wgsd_assets_lt_oth,wgsd_assets_lt,wgsd_lend_ib,wgsd_sec_colla,wgsd_loans_net,wgsd_loans_hfs,wgsd_assets_oth,wgsd_invest_oth,wgsd_receiv_insur,wgsd_def_plcy_acq_costs,wgsd_receiv_reinsur,wgsd_receiv_net,wgsd_receiv_st_oth,wgsd_loans_mtg_net,wgsd_real_estate_net,wgsd_ppe_net_oth,wgsd_assets,wgsd_pay_acct,wgsd_pay_tax,wgsd_liabs_trading,wgsd_debt_st,wgsd_liabs_curr_oth,wgsd_liabs_curr,wgsd_debt_lt,wgsd_liabs_lt_oth,wgsd_liabs_lt,wgsd_deposits,wgsd_borrow_ib,wgsd_fin_colla,wgsd_liabs_oth,wgsd_liabs_insur_contract,wgsd_pay_reinsur,wgsd_liabs_invest_contract,wgsd_liabs,wgsd_pfd_stk,wgsd_com_eq_par,wgsd_rsv,wgsd_apic,wgsd_com_eq_retain_earn,wgsd_rsv_other,wgsd_treas_stk,wgsd_com_eq_for_exch,wgsd_com_eq_paholder,wgsd_com_eq,wgsd_min_int,wgsd_stkhldrs_eq,wgsd_liabs_stkhldrs_eq,wgsd_sales_oper,wgsd_sales_oth,wgsd_sales,wgsd_int_inc_net,wgsd_int_inc,wgsd_fee_comm_inc_net,wgsd_fee_comm_inc,wgsd_trade_inc_net,wgsd_premiums_earned,wgsd_rev_rent,wgsd_tenant_reim_exp,wgsd_gain_sale_real_estate,wgsd_mtg_inc,wgsd_oper_cost,wgsd_oper_exp,wgsd_sga_exp,wgsd_rd_exp,wgsd_oper_exp_tot,wgsd_ebit_oper,wgsd_int_exp,wgsd_prov_loan_loss,wgsd_fee_comm_exp,wgsd_invest_gain,wgsd_no_oper_inc,wgsd_ebt_excl_unusual_items,wgsd_unusual_items,wgsd_inc_pretax,wgsd_inc_tax,wgsd_min_int_exp,wgsd_continue_oper,wgsd_disc_oper,wgsd_exod,wgsd_net_inc,wgsd_dvd_pfd_adj,wgsd_net_inc_dil,wgsd_compr_inc,is_sharepayments,is_ebitda_ard,wgsd_net_inc_cf,wgsd_dep_exp_cf,wgsd_wkcap_chg,wgsd_non_cash_chg,wgsd_oper_cf,wgsd_capex_ff,wgsd_assets_bus_cf,wgsd_invest_purch_cf,wgsd_invest_sale_cf,wgsd_invest_oth_cf,wgsd_invest_cf,wgsd_debt_iss_cf,wgsd_debt_reduct_cf,wgsd_stk_purch_cf,wgsd_stk_sale_cf,wgsd_div_cf,wgsd_fin_oth_cf,wgsd_fin_cf,wgsd_chg_cash_cf,wgsd_cash_beg_bal_cf,wgsd_cash_end_bal_cf,wgsd_for_exch_cf,wgsd_cash_bal_chg_cf,wgsd_turndays,wgsd_invturndays,wgsd_arturndays,wgsd_arturn,wgsd_invturn,wgsd_caturn,wgsd_faturn,wgsd_assetsturn,total_shares","unit=1;rptDate=20151231;rptType=1;currencyType=")
statement_2014=w.wss("A.N,AAL.O,AAP.N,AAPL.O,ABBV.N,ABC.N,ABT.N,ACN.N,ADBE.O,ADI.O,ADM.N,ADP.O,ADS.N,ADSK.O,AEE.N,AEP.N,AES.N,AET.N,AFL.N,AGN.N,AIG.N,AIV.N,AIZ.N,AJG.N,AKAM.O,ALB.N,ALGN.O,ALK.N,ALL.N,ALLE.N,ALXN.O,AMAT.O,AMD.O,AME.N,AMG.N,AMGN.O,AMP.N,AMT.N,AMZN.O,ANDV.N,ANSS.O,ANTM.N,AON.N,AOS.N,APA.N,APC.N,APD.N,APH.N,APTV.N,ARE.N,ARNC.N,ATVI.O,AVB.N,AVGO.O,AVY.N,AWK.N,AXP.N,AYI.N,AZO.N,BA.N,BAC.N,BAX.N,BBT.N,BBY.N,BDX.N,BEN.N,BF_B.N,BHF.O,BHGE.N,BIIB.O,BK.N,BLK.N,BLL.N,BMY.N,BRK_B.N,BSX.N,BWA.N,BXP.N,C.N,CA.O,CAG.N,CAH.N,CAT.N,CB.N,CBG.N,CBOE.O,CBS.N,CCI.N,CCL.N,CDNS.O,CELG.O,CERN.O,CF.N,CFG.N,CHD.N,CHK.N,CHRW.O,CHTR.O,CI.N,CINF.O,CL.N,CLX.N,CMA.N,CMCSA.O,CME.O,CMG.N,CMI.N,CMS.N,CNC.N,CNP.N,COF.N,COG.N,COL.N,COO.N,COP.N,COST.O,COTY.N,CPB.N,CRM.N,CSCO.O,CSRA.N,CSX.O,CTAS.O,CTL.N,CTSH.O,CTXS.O,CVS.N,CVX.N,CXO.N,D.N,DAL.N,DE.N,DFS.N,DG.N,DGX.N,DHI.N,DHR.N,DIS.N,DISCA.O,DISCK.O,DISH.O,DLR.N,DLTR.O,DOV.N,DPS.N,DRE.N,DRI.N,DTE.N,DUK.N,DVA.N,DVN.N,DWDP.N,DXC.N,EA.O,EBAY.O,ECL.N,ED.N,EFX.N,EIX.N,EL.N,EMN.N,EMR.N,EOG.N,EQIX.O,EQR.N,EQT.N,ES.N,ESRX.O,ESS.N,ETFC.O,ETN.N,ETR.N,EVHC.N,EW.N,EXC.N,EXPD.O,EXPE.O,EXR.N,F.N,FAST.O,FB.O,FBHS.N,FCX.N,FDX.N,FE.N,FFIV.O,FIS.N,FISV.O,FITB.O,FL.N,FLIR.O,FLR.N,FLS.N,FMC.N,FOX.O,FOXA.O,FRT.N,FTI.N,FTV.N,GD.N,GE.N,GGP.N,GILD.O,GIS.N,GLW.N,GM.N,GOOG.O,GOOGL.O,GPC.N,GPN.N,GPS.N,GRMN.O,GS.N,GT.O,GWW.N,HAL.N,HAS.O,HBAN.O,HBI.N,HCA.N,HCN.N,HCP.N,HD.N,HES.N,HIG.N,HII.N,HLT.N,HOG.N,HOLX.O,HON.N,HP.N,HPE.N,HPQ.N,HRB.N,HRL.N,HRS.N,HSIC.O,HST.N,HSY.N,HUM.N,IBM.N,ICE.N,IDXX.O,IFF.N,ILMN.O,INCY.O,INFO.O,INTC.O,INTU.O,IP.N,IPG.N,IQV.N,IR.N,IRM.N,ISRG.O,IT.N,ITW.N,IVZ.N,JBHT.O,JCI.N,JEC.N,JNJ.N,JNPR.N,JPM.N,JWN.N,K.N,KEY.N,KHC.O,KIM.N,KLAC.O,KMB.N,KMI.N,KMX.N,KO.N,KORS.N,KR.N,KSS.N,KSU.N,L.N,LB.N,LEG.N,LEN.N,LH.N,LKQ.O,LLL.N,LLY.N,LMT.N,LNC.N,LNT.N,LOW.N,LRCX.O,LUK.N,LUV.N,LYB.N,M.N,MA.N,MAA.N,MAC.N,MAR.O,MAS.N,MAT.O,MCD.N,MCHP.O,MCK.N,MCO.N,MDLZ.O,MDT.N,MET.N,MGM.N,MHK.N,MKC.N,MLM.N,MMC.N,MMM.N,MNST.O,MO.N,MON.N,MOS.N,MPC.N,MRK.N,MRO.N,MS.N,MSFT.O,MSI.N,MTB.N,MTD.N,MU.O,MYL.O,NAVI.O,NBL.N,NCLH.N,NDAQ.O,NEE.N,NEM.N,NFLX.O,NFX.N,NI.N,NKE.N,NLSN.N,NOC.N,NOV.N,NRG.N,NSC.N,NTAP.O,NTRS.O,NUE.N,NVDA.O,NWL.N,NWS.O,NWSA.O,O.N,OKE.N,OMC.N,ORCL.N,ORLY.O,OXY.N,PAYX.O,PBCT.O,PCAR.O,PCG.N,PCLN.O,PDCO.O,PEG.N,PEP.O,PFE.N,PFG.O,PG.N,PGR.N,PH.N,PHM.N,PKG.N,PKI.N,PLD.N,PM.N,PNC.N,PNR.N,PNW.N,PPG.N,PPL.N,PRGO.N,PRU.N,PSA.N,PSX.N,PVH.N,PWR.N,PX.N,PXD.N,PYPL.O,QCOM.O,QRVO.O,RCL.N,RE.N,REG.N,REGN.O,RF.N,RHI.N,RHT.N,RJF.N,RL.N,RMD.N,ROK.N,ROP.N,ROST.O,RRC.N,RSG.N,RTN.N,SBAC.O,SBUX.O,SCG.N,SCHW.N,SEE.N,SHW.N,SIG.N,SJM.N,SLB.N,SLG.N,SNA.N,SNI.O,SNPS.O,SO.N,SPG.N,SPGI.N,SRCL.O,SRE.N,STI.N,STT.N,STX.O,STZ.N,SWK.N,SWKS.O,SYF.N,SYK.N,SYMC.O,SYY.N,T.N,TAP.N,TDG.N,TEL.N,TGT.N,TIF.N,TJX.N,TMK.N,TMO.N,TPR.N,TRIP.O,TROW.O,TRV.N,TSCO.O,TSN.N,TSS.N,TWX.N,TXN.O,TXT.N,UA.N,UAA.N,UAL.N,UDR.N,UHS.N,ULTA.O,UNH.N,UNM.N,UNP.N,UPS.N,URI.N,USB.N,UTX.N,V.N,VAR.N,VFC.N,VIAB.O,VLO.N,VMC.N,VNO.N,VRSK.O,VRSN.O,VRTX.O,VTR.N,VZ.N,WAT.N,WBA.O,WDC.O,WEC.N,WFC.N,WHR.N,WLTW.O,WM.N,WMB.N,WMT.N,WRK.N,WU.N,WY.N,WYN.N,WYNN.O,XEC.N,XEL.O,XL.N,XLNX.O,XOM.N,XRAY.O,XRX.N,XYL.N,YUM.N,ZBH.N,ZION.O,ZTS.N", "wgsd_cce,wgsd_invest_trading,wgsd_invest_st_oth,wgsd_receiv_tot,wgsd_inventories,wgsd_assets_curr_oth,wgsd_assets_curr,wgsd_ppe_net,wgsd_invest_eq,wgsd_invest_htm,wgsd_invest_afs,wgsd_invest_lt_oth,wgsd_gw_intang_,wgsd_land_use_rights,wgsd_assets_lt_oth,wgsd_assets_lt,wgsd_lend_ib,wgsd_sec_colla,wgsd_loans_net,wgsd_loans_hfs,wgsd_assets_oth,wgsd_invest_oth,wgsd_receiv_insur,wgsd_def_plcy_acq_costs,wgsd_receiv_reinsur,wgsd_receiv_net,wgsd_receiv_st_oth,wgsd_loans_mtg_net,wgsd_real_estate_net,wgsd_ppe_net_oth,wgsd_assets,wgsd_pay_acct,wgsd_pay_tax,wgsd_liabs_trading,wgsd_debt_st,wgsd_liabs_curr_oth,wgsd_liabs_curr,wgsd_debt_lt,wgsd_liabs_lt_oth,wgsd_liabs_lt,wgsd_deposits,wgsd_borrow_ib,wgsd_fin_colla,wgsd_liabs_oth,wgsd_liabs_insur_contract,wgsd_pay_reinsur,wgsd_liabs_invest_contract,wgsd_liabs,wgsd_pfd_stk,wgsd_com_eq_par,wgsd_rsv,wgsd_apic,wgsd_com_eq_retain_earn,wgsd_rsv_other,wgsd_treas_stk,wgsd_com_eq_for_exch,wgsd_com_eq_paholder,wgsd_com_eq,wgsd_min_int,wgsd_stkhldrs_eq,wgsd_liabs_stkhldrs_eq,wgsd_sales_oper,wgsd_sales_oth,wgsd_sales,wgsd_int_inc_net,wgsd_int_inc,wgsd_fee_comm_inc_net,wgsd_fee_comm_inc,wgsd_trade_inc_net,wgsd_premiums_earned,wgsd_rev_rent,wgsd_tenant_reim_exp,wgsd_gain_sale_real_estate,wgsd_mtg_inc,wgsd_oper_cost,wgsd_oper_exp,wgsd_sga_exp,wgsd_rd_exp,wgsd_oper_exp_tot,wgsd_ebit_oper,wgsd_int_exp,wgsd_prov_loan_loss,wgsd_fee_comm_exp,wgsd_invest_gain,wgsd_no_oper_inc,wgsd_ebt_excl_unusual_items,wgsd_unusual_items,wgsd_inc_pretax,wgsd_inc_tax,wgsd_min_int_exp,wgsd_continue_oper,wgsd_disc_oper,wgsd_exod,wgsd_net_inc,wgsd_dvd_pfd_adj,wgsd_net_inc_dil,wgsd_compr_inc,is_sharepayments,is_ebitda_ard,wgsd_net_inc_cf,wgsd_dep_exp_cf,wgsd_wkcap_chg,wgsd_non_cash_chg,wgsd_oper_cf,wgsd_capex_ff,wgsd_assets_bus_cf,wgsd_invest_purch_cf,wgsd_invest_sale_cf,wgsd_invest_oth_cf,wgsd_invest_cf,wgsd_debt_iss_cf,wgsd_debt_reduct_cf,wgsd_stk_purch_cf,wgsd_stk_sale_cf,wgsd_div_cf,wgsd_fin_oth_cf,wgsd_fin_cf,wgsd_chg_cash_cf,wgsd_cash_beg_bal_cf,wgsd_cash_end_bal_cf,wgsd_for_exch_cf,wgsd_cash_bal_chg_cf,wgsd_turndays,wgsd_invturndays,wgsd_arturndays,wgsd_arturn,wgsd_invturn,wgsd_caturn,wgsd_faturn,wgsd_assetsturn,total_shares","unit=1;rptDate=20141231;rptType=1;currencyType=")
statement_2013=w.wss("A.N,AAL.O,AAP.N,AAPL.O,ABBV.N,ABC.N,ABT.N,ACN.N,ADBE.O,ADI.O,ADM.N,ADP.O,ADS.N,ADSK.O,AEE.N,AEP.N,AES.N,AET.N,AFL.N,AGN.N,AIG.N,AIV.N,AIZ.N,AJG.N,AKAM.O,ALB.N,ALGN.O,ALK.N,ALL.N,ALLE.N,ALXN.O,AMAT.O,AMD.O,AME.N,AMG.N,AMGN.O,AMP.N,AMT.N,AMZN.O,ANDV.N,ANSS.O,ANTM.N,AON.N,AOS.N,APA.N,APC.N,APD.N,APH.N,APTV.N,ARE.N,ARNC.N,ATVI.O,AVB.N,AVGO.O,AVY.N,AWK.N,AXP.N,AYI.N,AZO.N,BA.N,BAC.N,BAX.N,BBT.N,BBY.N,BDX.N,BEN.N,BF_B.N,BHF.O,BHGE.N,BIIB.O,BK.N,BLK.N,BLL.N,BMY.N,BRK_B.N,BSX.N,BWA.N,BXP.N,C.N,CA.O,CAG.N,CAH.N,CAT.N,CB.N,CBG.N,CBOE.O,CBS.N,CCI.N,CCL.N,CDNS.O,CELG.O,CERN.O,CF.N,CFG.N,CHD.N,CHK.N,CHRW.O,CHTR.O,CI.N,CINF.O,CL.N,CLX.N,CMA.N,CMCSA.O,CME.O,CMG.N,CMI.N,CMS.N,CNC.N,CNP.N,COF.N,COG.N,COL.N,COO.N,COP.N,COST.O,COTY.N,CPB.N,CRM.N,CSCO.O,CSRA.N,CSX.O,CTAS.O,CTL.N,CTSH.O,CTXS.O,CVS.N,CVX.N,CXO.N,D.N,DAL.N,DE.N,DFS.N,DG.N,DGX.N,DHI.N,DHR.N,DIS.N,DISCA.O,DISCK.O,DISH.O,DLR.N,DLTR.O,DOV.N,DPS.N,DRE.N,DRI.N,DTE.N,DUK.N,DVA.N,DVN.N,DWDP.N,DXC.N,EA.O,EBAY.O,ECL.N,ED.N,EFX.N,EIX.N,EL.N,EMN.N,EMR.N,EOG.N,EQIX.O,EQR.N,EQT.N,ES.N,ESRX.O,ESS.N,ETFC.O,ETN.N,ETR.N,EVHC.N,EW.N,EXC.N,EXPD.O,EXPE.O,EXR.N,F.N,FAST.O,FB.O,FBHS.N,FCX.N,FDX.N,FE.N,FFIV.O,FIS.N,FISV.O,FITB.O,FL.N,FLIR.O,FLR.N,FLS.N,FMC.N,FOX.O,FOXA.O,FRT.N,FTI.N,FTV.N,GD.N,GE.N,GGP.N,GILD.O,GIS.N,GLW.N,GM.N,GOOG.O,GOOGL.O,GPC.N,GPN.N,GPS.N,GRMN.O,GS.N,GT.O,GWW.N,HAL.N,HAS.O,HBAN.O,HBI.N,HCA.N,HCN.N,HCP.N,HD.N,HES.N,HIG.N,HII.N,HLT.N,HOG.N,HOLX.O,HON.N,HP.N,HPE.N,HPQ.N,HRB.N,HRL.N,HRS.N,HSIC.O,HST.N,HSY.N,HUM.N,IBM.N,ICE.N,IDXX.O,IFF.N,ILMN.O,INCY.O,INFO.O,INTC.O,INTU.O,IP.N,IPG.N,IQV.N,IR.N,IRM.N,ISRG.O,IT.N,ITW.N,IVZ.N,JBHT.O,JCI.N,JEC.N,JNJ.N,JNPR.N,JPM.N,JWN.N,K.N,KEY.N,KHC.O,KIM.N,KLAC.O,KMB.N,KMI.N,KMX.N,KO.N,KORS.N,KR.N,KSS.N,KSU.N,L.N,LB.N,LEG.N,LEN.N,LH.N,LKQ.O,LLL.N,LLY.N,LMT.N,LNC.N,LNT.N,LOW.N,LRCX.O,LUK.N,LUV.N,LYB.N,M.N,MA.N,MAA.N,MAC.N,MAR.O,MAS.N,MAT.O,MCD.N,MCHP.O,MCK.N,MCO.N,MDLZ.O,MDT.N,MET.N,MGM.N,MHK.N,MKC.N,MLM.N,MMC.N,MMM.N,MNST.O,MO.N,MON.N,MOS.N,MPC.N,MRK.N,MRO.N,MS.N,MSFT.O,MSI.N,MTB.N,MTD.N,MU.O,MYL.O,NAVI.O,NBL.N,NCLH.N,NDAQ.O,NEE.N,NEM.N,NFLX.O,NFX.N,NI.N,NKE.N,NLSN.N,NOC.N,NOV.N,NRG.N,NSC.N,NTAP.O,NTRS.O,NUE.N,NVDA.O,NWL.N,NWS.O,NWSA.O,O.N,OKE.N,OMC.N,ORCL.N,ORLY.O,OXY.N,PAYX.O,PBCT.O,PCAR.O,PCG.N,PCLN.O,PDCO.O,PEG.N,PEP.O,PFE.N,PFG.O,PG.N,PGR.N,PH.N,PHM.N,PKG.N,PKI.N,PLD.N,PM.N,PNC.N,PNR.N,PNW.N,PPG.N,PPL.N,PRGO.N,PRU.N,PSA.N,PSX.N,PVH.N,PWR.N,PX.N,PXD.N,PYPL.O,QCOM.O,QRVO.O,RCL.N,RE.N,REG.N,REGN.O,RF.N,RHI.N,RHT.N,RJF.N,RL.N,RMD.N,ROK.N,ROP.N,ROST.O,RRC.N,RSG.N,RTN.N,SBAC.O,SBUX.O,SCG.N,SCHW.N,SEE.N,SHW.N,SIG.N,SJM.N,SLB.N,SLG.N,SNA.N,SNI.O,SNPS.O,SO.N,SPG.N,SPGI.N,SRCL.O,SRE.N,STI.N,STT.N,STX.O,STZ.N,SWK.N,SWKS.O,SYF.N,SYK.N,SYMC.O,SYY.N,T.N,TAP.N,TDG.N,TEL.N,TGT.N,TIF.N,TJX.N,TMK.N,TMO.N,TPR.N,TRIP.O,TROW.O,TRV.N,TSCO.O,TSN.N,TSS.N,TWX.N,TXN.O,TXT.N,UA.N,UAA.N,UAL.N,UDR.N,UHS.N,ULTA.O,UNH.N,UNM.N,UNP.N,UPS.N,URI.N,USB.N,UTX.N,V.N,VAR.N,VFC.N,VIAB.O,VLO.N,VMC.N,VNO.N,VRSK.O,VRSN.O,VRTX.O,VTR.N,VZ.N,WAT.N,WBA.O,WDC.O,WEC.N,WFC.N,WHR.N,WLTW.O,WM.N,WMB.N,WMT.N,WRK.N,WU.N,WY.N,WYN.N,WYNN.O,XEC.N,XEL.O,XL.N,XLNX.O,XOM.N,XRAY.O,XRX.N,XYL.N,YUM.N,ZBH.N,ZION.O,ZTS.N", "wgsd_cce,wgsd_invest_trading,wgsd_invest_st_oth,wgsd_receiv_tot,wgsd_inventories,wgsd_assets_curr_oth,wgsd_assets_curr,wgsd_ppe_net,wgsd_invest_eq,wgsd_invest_htm,wgsd_invest_afs,wgsd_invest_lt_oth,wgsd_gw_intang_,wgsd_land_use_rights,wgsd_assets_lt_oth,wgsd_assets_lt,wgsd_lend_ib,wgsd_sec_colla,wgsd_loans_net,wgsd_loans_hfs,wgsd_assets_oth,wgsd_invest_oth,wgsd_receiv_insur,wgsd_def_plcy_acq_costs,wgsd_receiv_reinsur,wgsd_receiv_net,wgsd_receiv_st_oth,wgsd_loans_mtg_net,wgsd_real_estate_net,wgsd_ppe_net_oth,wgsd_assets,wgsd_pay_acct,wgsd_pay_tax,wgsd_liabs_trading,wgsd_debt_st,wgsd_liabs_curr_oth,wgsd_liabs_curr,wgsd_debt_lt,wgsd_liabs_lt_oth,wgsd_liabs_lt,wgsd_deposits,wgsd_borrow_ib,wgsd_fin_colla,wgsd_liabs_oth,wgsd_liabs_insur_contract,wgsd_pay_reinsur,wgsd_liabs_invest_contract,wgsd_liabs,wgsd_pfd_stk,wgsd_com_eq_par,wgsd_rsv,wgsd_apic,wgsd_com_eq_retain_earn,wgsd_rsv_other,wgsd_treas_stk,wgsd_com_eq_for_exch,wgsd_com_eq_paholder,wgsd_com_eq,wgsd_min_int,wgsd_stkhldrs_eq,wgsd_liabs_stkhldrs_eq,wgsd_sales_oper,wgsd_sales_oth,wgsd_sales,wgsd_int_inc_net,wgsd_int_inc,wgsd_fee_comm_inc_net,wgsd_fee_comm_inc,wgsd_trade_inc_net,wgsd_premiums_earned,wgsd_rev_rent,wgsd_tenant_reim_exp,wgsd_gain_sale_real_estate,wgsd_mtg_inc,wgsd_oper_cost,wgsd_oper_exp,wgsd_sga_exp,wgsd_rd_exp,wgsd_oper_exp_tot,wgsd_ebit_oper,wgsd_int_exp,wgsd_prov_loan_loss,wgsd_fee_comm_exp,wgsd_invest_gain,wgsd_no_oper_inc,wgsd_ebt_excl_unusual_items,wgsd_unusual_items,wgsd_inc_pretax,wgsd_inc_tax,wgsd_min_int_exp,wgsd_continue_oper,wgsd_disc_oper,wgsd_exod,wgsd_net_inc,wgsd_dvd_pfd_adj,wgsd_net_inc_dil,wgsd_compr_inc,is_sharepayments,is_ebitda_ard,wgsd_net_inc_cf,wgsd_dep_exp_cf,wgsd_wkcap_chg,wgsd_non_cash_chg,wgsd_oper_cf,wgsd_capex_ff,wgsd_assets_bus_cf,wgsd_invest_purch_cf,wgsd_invest_sale_cf,wgsd_invest_oth_cf,wgsd_invest_cf,wgsd_debt_iss_cf,wgsd_debt_reduct_cf,wgsd_stk_purch_cf,wgsd_stk_sale_cf,wgsd_div_cf,wgsd_fin_oth_cf,wgsd_fin_cf,wgsd_chg_cash_cf,wgsd_cash_beg_bal_cf,wgsd_cash_end_bal_cf,wgsd_for_exch_cf,wgsd_cash_bal_chg_cf,wgsd_turndays,wgsd_invturndays,wgsd_arturndays,total_shares,wgsd_arturn,wgsd_invturn,wgsd_caturn,wgsd_faturn,wgsd_assetsturn,total_shares","unit=1;rptDate=20131231;rptType=1;currencyType=")

clsprice_a=w.wsd("SP500.SPI,A.N,AAL.O,AAP.N,AAPL.O,ABBV.N,ABC.N,ABT.N,ACN.N,ADBE.O,ADI.O,ADM.N,ADP.O,ADS.N,ADSK.O,AEE.N,AEP.N,AES.N,AET.N,AFL.N,AGN.N,AIG.N,AIV.N,AIZ.N,AJG.N,AKAM.O,ALB.N,ALGN.O,ALK.N,ALL.N,ALLE.N,ALXN.O,AMAT.O,AMD.O,AME.N,AMG.N,AMGN.O,AMP.N,AMT.N,AMZN.O,ANDV.N,ANSS.O,ANTM.N,AON.N,AOS.N,APA.N,APC.N,APD.N,APH.N,APTV.N,ARE.N,ARNC.N,ATVI.O,AVB.N,AVGO.O,AVY.N,AWK.N,AXP.N,AYI.N,AZO.N,BA.N,BAC.N,BAX.N,BBT.N,BBY.N,BDX.N,BEN.N,BF_B.N,BHF.O,BHGE.N,BIIB.O,BK.N,BLK.N,BLL.N,BMY.N,BRK_B.N,BSX.N,BWA.N,BXP.N,C.N,CA.O,CAG.N,CAH.N,CAT.N,CB.N,CBG.N,CBOE.O,CBS.N,CCI.N,CCL.N,CDNS.O,CELG.O,CERN.O,CF.N,CFG.N,CHD.N,CHK.N,CHRW.O,CHTR.O,CI.N,CINF.O,CL.N,CLX.N,CMA.N,CMCSA.O,CME.O,CMG.N,CMI.N,CMS.N,CNC.N,CNP.N,COF.N,COG.N,COL.N,COO.N,COP.N,COST.O,COTY.N,CPB.N,CRM.N,CSCO.O,CSRA.N,CSX.O,CTAS.O,CTL.N,CTSH.O,CTXS.O,CVS.N,CVX.N,CXO.N,D.N,DAL.N,DE.N,DFS.N,DG.N,DGX.N,DHI.N,DHR.N,DIS.N,DISCA.O,DISCK.O,DISH.O,DLR.N,DLTR.O,DOV.N,DPS.N,DRE.N,DRI.N,DTE.N,DUK.N,DVA.N,DVN.N,DWDP.N,DXC.N,EA.O,EBAY.O,ECL.N,ED.N,EFX.N,EIX.N,EL.N,EMN.N,EMR.N,EOG.N,EQIX.O,EQR.N,EQT.N,ES.N,ESRX.O,ESS.N,ETFC.O,ETN.N,ETR.N,EVHC.N,EW.N,EXC.N,EXPD.O,EXPE.O,EXR.N,F.N,FAST.O,FB.O,FBHS.N,FCX.N,FDX.N,FE.N,FFIV.O,FIS.N,FISV.O,FITB.O,FL.N,FLIR.O,FLR.N,FLS.N,FMC.N,FOX.O,FOXA.O,FRT.N,FTI.N,FTV.N,GD.N,GE.N,GGP.N,GILD.O,GIS.N,GLW.N,GM.N,GOOG.O,GOOGL.O,GPC.N,GPN.N,GPS.N,GRMN.O,GS.N,GT.O,GWW.N,HAL.N,HAS.O,HBAN.O,HBI.N,HCA.N,HCN.N,HCP.N,HD.N,HES.N,HIG.N,HII.N,HLT.N,HOG.N,HOLX.O,HON.N,HP.N,HPE.N,HPQ.N,HRB.N,HRL.N,HRS.N,HSIC.O,HST.N,HSY.N,HUM.N,IBM.N,ICE.N,IDXX.O,IFF.N,ILMN.O,INCY.O,INFO.O,INTC.O,INTU.O,IP.N,IPG.N,IQV.N,IR.N,IRM.N,ISRG.O,IT.N,ITW.N,IVZ.N,JBHT.O,JCI.N,JEC.N,JNJ.N,JNPR.N,JPM.N,JWN.N,K.N,KEY.N,KHC.O,KIM.N,KLAC.O,KMB.N,KMI.N,KMX.N,KO.N,KORS.N,KR.N,KSS.N,KSU.N,L.N,LB.N,LEG.N,LEN.N,LH.N,LKQ.O,LLL.N,LLY.N,LMT.N,LNC.N,LNT.N,LOW.N,LRCX.O,LUK.N,LUV.N,LYB.N,M.N,MA.N,MAA.N,MAC.N,MAR.O,MAS.N,MAT.O,MCD.N,MCHP.O,MCK.N,MCO.N,MDLZ.O,MDT.N,MET.N,MGM.N,MHK.N,MKC.N,MLM.N,MMC.N,MMM.N,MNST.O,MO.N,MON.N,MOS.N,MPC.N,MRK.N,MRO.N,MS.N,MSFT.O,MSI.N,MTB.N,MTD.N,MU.O,MYL.O,NAVI.O,NBL.N,NCLH.N,NDAQ.O,NEE.N,NEM.N,NFLX.O,NFX.N,NI.N,NKE.N,NLSN.N,NOC.N,NOV.N,NRG.N,NSC.N,NTAP.O,NTRS.O,NUE.N,NVDA.O,NWL.N,NWS.O,NWSA.O,O.N,OKE.N,OMC.N,ORCL.N,ORLY.O,OXY.N,PAYX.O,PBCT.O,PCAR.O,PCG.N,PCLN.O,PDCO.O,PEG.N,PEP.O,PFE.N,PFG.O,PG.N,PGR.N,PH.N,PHM.N,PKG.N,PKI.N,PLD.N,PM.N,PNC.N,PNR.N,PNW.N,PPG.N,PPL.N,PRGO.N,PRU.N,PSA.N,PSX.N,PVH.N,PWR.N,PX.N,PXD.N,PYPL.O,QCOM.O,QRVO.O,RCL.N,RE.N,REG.N,REGN.O,RF.N,RHI.N,RHT.N,RJF.N,RL.N,RMD.N,ROK.N,ROP.N,ROST.O,RRC.N,RSG.N,RTN.N,SBAC.O,SBUX.O,SCG.N,SCHW.N,SEE.N,SHW.N,SIG.N,SJM.N,SLB.N,SLG.N,SNA.N,SNI.O,SNPS.O,SO.N,SPG.N,SPGI.N,SRCL.O,SRE.N,STI.N,STT.N,STX.O,STZ.N,SWK.N,SWKS.O,SYF.N,SYK.N,SYMC.O,SYY.N,T.N,TAP.N,TDG.N,TEL.N,TGT.N,TIF.N,TJX.N,TMK.N,TMO.N,TPR.N,TRIP.O,TROW.O,TRV.N,TSCO.O,TSN.N,TSS.N,TWX.N,TXN.O,TXT.N,UA.N,UAA.N,UAL.N,UDR.N,UHS.N,ULTA.O,UNH.N,UNM.N,UNP.N,UPS.N,URI.N,USB.N,UTX.N,V.N,VAR.N,VFC.N,VIAB.O,VLO.N,VMC.N,VNO.N,VRSK.O,VRSN.O,VRTX.O,VTR.N,VZ.N,WAT.N,WBA.O,WDC.O,WEC.N,WFC.N,WHR.N,WLTW.O,WM.N,WMB.N,WMT.N,WRK.N,WU.N,WY.N,WYN.N,WYNN.O,XEC.N,XEL.O,XL.N,XLNX.O,XOM.N,XRAY.O,XRX.N,XYL.N,YUM.N,ZBH.N,ZION.O,ZTS.N", "close", "2014-12-31", "2016-12-31", "Fill=Previous")

# %%
##get companies' BETAs and res
#get the data from Wind
#a is the data, a.Codes contains codes of stocks, a.Data contains data of stocks the period is 20141231 --- 20161231
#take Wind data to Dataframe

beta_i=2
beta_b=pd.DataFrame(data={'rm':clsprice_a.Data[0],clsprice_a.Codes[1]:clsprice_a.Data[1]},index=clsprice_a.Times)
while beta_i <len(clsprice_a.Codes):
    beta_b[clsprice_a.Codes[beta_i]]=clsprice_a.Data[beta_i]
    beta_i=beta_i+1
beta_b.T
beta_b.dropna(how='any')
beta_b.T
beta_c=pd.DataFrame(beta_b[0:len(beta_b.rm):5])#get the 5-days interval data 
beta_d=beta_c[:len(beta_b.rm)].diff(-1) * -1#do the difference
beta_e=beta_d/beta_c#show the rate of return for five days
beta_rf=0.02
beta_fivedays_rf=(0.02+1)**(1/52)-1 #calculate US five-days risk-free rate---------------rf should be renewed if more info is available
                           # because I do not know how to get a trustworthy rf from Wind Database
beta_f=beta_e-beta_fivedays_rf#create the list of risk free rate 
var_rm2rf=np.var(beta_e.rm)
beta_g=beta_f.iloc[0:-1,:]#exclude the last row
beta_j=0
beta=pd.DataFrame()
while beta_j<len(clsprice_a.Codes):
    beta[clsprice_a.Codes[beta_j]]=[(np.cov((beta_g.iloc[:,beta_j],beta_g.rm),bias=1)[0,1]/var_rm2rf)]
    beta_j=beta_j+1
print('betas of each companies:','\n',beta.iloc[0:6,0:6]) #don't know why, beta:SP500.SPI should be 1 and beta:A.N should be 1.164612
                                      #in case of causing severe problems, I do not drop the first column and add it to the second place
beta.to_excel('d:/RIV/equity_beta.xlsx')
beta_rm=(1+(beta_b.iloc[:,1][-1]-beta_b.iloc[:,1][0])/beta_b.iloc[:,1][0])**0.5-1 #get the return of market
re=beta*(beta_rm-beta_rf)+beta_rf
print('\n','the equity return of each companies:','\n',re.iloc[0:6,0:6])
re_T=re.T
re_T.columns=['equity_return',]
re=re_T.T
re.to_excel('d:/RIV/equity_return.xlsx')



b=pd.DataFrame({})
i=0
while i<len(statement_2016.Fields):
    b[statement_2016.Fields[i]]=statement_2016.Data[i]
    i=i+1

c=b.T
c.columns = statement_2016.Codes
bs=c.T

bs.fillna(0,inplace=True)#transfer NaN to 0
WGSD_CCE_OPER=bs.WGSD_CCE*0.01#separate cash to operating & financing asset
WGSD_CCE_FINC=bs.WGSD_CCE*0.99
WGSD_INVEST_TRADING_FINC=bs.WGSD_INVEST_TRADING
WGSD_INVEST_ST_OTH_FINC=bs.WGSD_INVEST_ST_OTH
WGSD_RECEIV_NET_OPER=bs.WGSD_RECEIV_NET
WGSD_INVENTORIES_OPER=bs.WGSD_INVENTORIES
WGSD_ASSETS_CURR_OTH_OPER=bs.WGSD_ASSETS_CURR_OTH
WGSD_PPE_NET_OPER=bs.WGSD_PPE_NET
WGSD_INVEST_EQ_FINC=bs.WGSD_INVEST_EQ
WGSD_INVEST_HTM_FINC=bs.WGSD_INVEST_HTM
WGSD_INVEST_AFS_FINC=bs.WGSD_INVEST_AFS
WGSD_INVEST_LT_OTH_FINC=bs.WGSD_INVEST_LT_OTH
WGSD_GW_INTANG_OPER=bs.WGSD_GW_INTANG_
WGSD_LAND_USE_RIGHTS_OPER=bs.WGSD_LAND_USE_RIGHTS
WGSD_ASSETS_LT_OTH_OPER=bs.WGSD_ASSETS_LT_OTH
WGSD_LEND_IB_FINC=bs.WGSD_LEND_IB
WGSD_SEC_COLLA_FINC=bs.WGSD_SEC_COLLA
WGSD_LOANS_NET_FINC=bs.WGSD_LOANS_NET
WGSD_LOANS_HFS_FINC=bs.WGSD_LOANS_HFS
WGSD_ASSETS_OTH_OPER=bs.WGSD_ASSETS_OTH
WGSD_INVEST_OTH_FINC=bs.WGSD_INVEST_OTH
WGSD_RECEIV_INSUR_OPER=bs.WGSD_RECEIV_INSUR
WGSD_DEF_PLCY_ACQ_COSTS_OPER=bs.WGSD_DEF_PLCY_ACQ_COSTS
WGSD_RECEIV_REINSUR_OPER=bs.WGSD_RECEIV_REINSUR
WGSD_RECEIV_ST_OTH_OPER=bs.WGSD_RECEIV_ST_OTH
WGSD_LOANS_MTG_NET_OPER=bs.WGSD_LOANS_MTG_NET
WGSD_REAL_ESTATE_NET_OPER=bs.WGSD_REAL_ESTATE_NET
WGSD_PPE_NET_OTH_OPER=bs.WGSD_PPE_NET_OTH

#add column to excel
#assets
bs['WGSD_CCE_OPER']=WGSD_CCE_OPER
bs['WGSD_CCE_FINC']=WGSD_CCE_FINC
bs['WGSD_INVEST_TRADING_FINC']=WGSD_INVEST_TRADING_FINC
bs['WGSD_INVEST_ST_OTH_FINC']=WGSD_INVEST_ST_OTH_FINC
bs['WGSD_RECEIV_NET_OPER']=WGSD_RECEIV_NET_OPER
bs['WGSD_INVENTORIES_OPER']=WGSD_INVENTORIES_OPER
bs['WGSD_ASSETS_CURR_OTH_OPER']=WGSD_ASSETS_CURR_OTH_OPER
bs['WGSD_PPE_NET_OPER']=WGSD_PPE_NET_OPER
bs['WGSD_INVEST_EQ_FINC']=WGSD_INVEST_EQ_FINC
bs['WGSD_INVEST_HTM_FINC']=WGSD_INVEST_HTM_FINC
bs['WGSD_INVEST_AFS_FINC']=WGSD_INVEST_AFS_FINC
bs['WGSD_INVEST_LT_OTH_FINC']=WGSD_INVEST_LT_OTH_FINC
bs['WGSD_GW_INTANG_OPER']=WGSD_GW_INTANG_OPER
bs['WGSD_LAND_USE_RIGHTS_OPER']=WGSD_LAND_USE_RIGHTS_OPER
bs['WGSD_ASSETS_LT_OTH_OPER']=WGSD_ASSETS_LT_OTH_OPER
bs['WGSD_LEND_IB_FINC']=WGSD_LEND_IB_FINC
bs['WGSD_SEC_COLLA_FINC']=WGSD_SEC_COLLA_FINC
bs['WGSD_LOANS_NET_FINC']=WGSD_LOANS_NET_FINC
bs['WGSD_LOANS_HFS_FINC']=WGSD_LOANS_HFS_FINC
bs['WGSD_ASSETS_OTH_OPER']=WGSD_ASSETS_OTH_OPER
bs['WGSD_INVEST_OTH_FINC']=WGSD_INVEST_OTH_FINC
bs['WGSD_RECEIV_INSUR_OPER']=WGSD_RECEIV_INSUR_OPER
bs['WGSD_DEF_PLCY_ACQ_COSTS_OPER']=WGSD_DEF_PLCY_ACQ_COSTS_OPER
bs['WGSD_RECEIV_REINSUR_OPER']=WGSD_RECEIV_REINSUR_OPER
bs['WGSD_RECEIV_ST_OTH_OPER']=WGSD_RECEIV_ST_OTH_OPER
bs['WGSD_LOANS_MTG_NET_OPER']=WGSD_LOANS_MTG_NET_OPER
bs['WGSD_REAL_ESTATE_NET_OPER']=WGSD_REAL_ESTATE_NET_OPER
bs['WGSD_PPE_NET_OTH_OPER']=WGSD_PPE_NET_OTH_OPER
#liabs&prefered_share
WGSD_PAY_ACCT_OPER=bs.WGSD_PAY_ACCT
WGSD_PAY_TAX_OPER=bs.WGSD_PAY_TAX
WGSD_LIABS_TRADING_FINC=bs.WGSD_LIABS_TRADING
WGSD_DEBT_ST_OPER=bs.WGSD_DEBT_ST
WGSD_LIABS_CURR_OTH_OPER=bs.WGSD_LIABS_CURR_OTH
WGSD_DEBT_LT_FINC=bs.WGSD_DEBT_LT
WGSD_LIABS_LT_OTH_FINC=bs.WGSD_LIABS_LT_OTH
WGSD_DEPOSITS_OPERXXX=bs.WGSD_DEPOSITS
WGSD_BORROW_IB_OPERXXX=bs.WGSD_BORROW_IB
WGSD_FIN_COLLA_FINC=bs.WGSD_FIN_COLLA
WGSD_LIABS_OTH_FINC=bs.WGSD_LIABS_OTH
WGSD_LIABS_INSUR_CONTRACT_OPER=bs.WGSD_LIABS_INSUR_CONTRACT
WGSD_PAY_REINSUR_OPER=bs.WGSD_PAY_REINSUR
WGSD_LIABS_INVEST_CONTRACT_OPER=bs.WGSD_LIABS_INVEST_CONTRACT
WGSD_PFD_STK_FINC=bs.WGSD_PFD_STK
bs['WGSD_PAY_ACCT_OPER']=WGSD_PAY_ACCT_OPER
bs['WGSD_PAY_TAX_OPER']=WGSD_PAY_TAX_OPER
bs['WGSD_LIABS_TRADING_FINC']=WGSD_LIABS_TRADING_FINC
bs['WGSD_DEBT_ST_OPER']=WGSD_DEBT_ST_OPER
bs['WGSD_LIABS_CURR_OTH_OPER']=WGSD_LIABS_CURR_OTH_OPER
bs['WGSD_DEBT_LT_FINC']=WGSD_DEBT_LT_FINC
bs['WGSD_LIABS_LT_OTH_FINC']=WGSD_LIABS_LT_OTH_FINC
bs['WGSD_DEPOSITS_OPERXXX']=WGSD_DEPOSITS_OPERXXX
bs['WGSD_BORROW_IB_OPERXXX']=WGSD_BORROW_IB_OPERXXX
bs['WGSD_FIN_COLLA_FINC']=WGSD_FIN_COLLA_FINC
bs['WGSD_LIABS_OTH_FINC']=WGSD_LIABS_OTH_FINC
bs['WGSD_LIABS_INSUR_CONTRACT_OPER']=WGSD_LIABS_INSUR_CONTRACT_OPER
bs['WGSD_PAY_REINSUR_OPER']=WGSD_PAY_REINSUR_OPER
bs['WGSD_LIABS_INVEST_CONTRACT_OPER']=WGSD_LIABS_INVEST_CONTRACT_OPER
bs['WGSD_PFD_STK_FINC']=WGSD_PFD_STK_FINC
##calculate NOA & NFA
#OA
WGSD_ASSET_TOT_OPER=bs.WGSD_CCE_OPER+bs.WGSD_RECEIV_NET_OPER+bs.WGSD_INVENTORIES_OPER+bs.WGSD_ASSETS_CURR_OTH_OPER\
+bs.WGSD_PPE_NET_OPER+bs.WGSD_GW_INTANG_OPER+bs.WGSD_LAND_USE_RIGHTS_OPER\
+bs.WGSD_ASSETS_LT_OTH_OPER+bs.WGSD_ASSETS_OTH_OPER+bs.WGSD_RECEIV_INSUR_OPER\
+bs.WGSD_DEF_PLCY_ACQ_COSTS_OPER+bs.WGSD_RECEIV_REINSUR_OPER\
+bs.WGSD_RECEIV_ST_OTH_OPER+bs.WGSD_LOANS_MTG_NET_OPER+bs.WGSD_REAL_ESTATE_NET_OPER+bs.WGSD_PPE_NET_OTH_OPER
#FA
WGSD_ASSET_TOT_FINC=bs.WGSD_CCE_FINC+bs.WGSD_INVEST_TRADING_FINC+bs.WGSD_INVEST_ST_OTH_FINC\
+bs.WGSD_INVEST_EQ_FINC+bs.WGSD_INVEST_HTM_FINC+bs.WGSD_INVEST_AFS_FINC\
+bs.WGSD_INVEST_LT_OTH_FINC+bs.WGSD_LEND_IB_FINC+bs.WGSD_SEC_COLLA_FINC\
+bs.WGSD_LOANS_NET_FINC+bs.WGSD_LOANS_HFS_FINC+bs.WGSD_INVEST_OTH_FINC
#LA
WGSD_LIABS_TOT_OPER=bs.WGSD_PAY_ACCT_OPER+bs.WGSD_PAY_TAX_OPER+bs.WGSD_DEBT_ST_OPER\
+bs.WGSD_LIABS_CURR_OTH_OPER+bs.WGSD_DEPOSITS_OPERXXX+bs.WGSD_BORROW_IB_OPERXXX\
+bs.WGSD_LIABS_INSUR_CONTRACT_OPER+bs.WGSD_PAY_REINSUR_OPER+bs.WGSD_LIABS_INVEST_CONTRACT_OPER
WGSD_LIABS_TOT_FINC=bs.WGSD_LIABS_TRADING_FINC+bs.WGSD_DEBT_LT_FINC+bs.WGSD_LIABS_LT_OTH_FINC\
+bs.WGSD_FIN_COLLA_FINC+bs.WGSD_LIABS_OTH_FINC+bs.WGSD_PFD_STK_FINC
bs['WGSD_ASSET_TOT_OPER']=WGSD_ASSET_TOT_OPER
bs['WGSD_ASSET_TOT_FINC']=WGSD_ASSET_TOT_FINC
bs['WGSD_LIABS_TOT_OPER']=WGSD_LIABS_TOT_OPER
bs['WGSD_LIABS_TOT_FINC']=WGSD_LIABS_TOT_FINC
#NOA & NFA
WGSD_NOA_ALPHA=bs.WGSD_ASSET_TOT_OPER-bs.WGSD_LIABS_TOT_OPER
WGSD_NFA_ALPHA=bs.WGSD_ASSET_TOT_FINC-bs.WGSD_LIABS_TOT_FINC
bs['WGSD_NOA_ALPHA']=WGSD_NOA_ALPHA
bs['WGSD_NFA_ALPHA']=WGSD_NFA_ALPHA
bs['WGSD_OTHER_NOA']=bs.WGSD_NOA_ALPHA-bs.WGSD_PPE_NET_OPER-bs.WGSD_INVENTORIES_OPER-bs.WGSD_RECEIV_NET_OPER
bs['WGSD_NET_INC_EXP']=bs['WGSD_INT_EXP']-bs['WGSD_INT_INC']
bs['WGSD_TAX_BENEFIT']=bs['WGSD_NET_INC_EXP']*0.38 # assume the corporate tax rate in USA is 38%
bs['WGSD_OPERATING_TAX']=bs['WGSD_TAX_BENEFIT']+bs['WGSD_INC_TAX']
bs['WGSD_INVENTORY_TURNOVER']=bs['WGSD_OPER_COST']/bs['WGSD_INVENTORIES']
bs['WGSD_PPE_TURNOVER']=bs['WGSD_SALES']/bs['WGSD_PPE_NET']
bs['WGSD_RECEIVABLES_TURNOVER']=bs['WGSD_SALES']/bs['WGSD_RECEIV_NET']
bs['WGSD_GROSS_MARGIN']=(bs['WGSD_SALES']-bs['WGSD_OPER_COST'])/bs['WGSD_SALES']
bs['WGSD_SGA_EXPENSE_RATIO']=(bs['WGSD_OPER_EXP']/bs['WGSD_SALES'])
bs['WGSD_OTHER_NOA2SALES']=bs['WGSD_OTHER_NOA']/bs['WGSD_SALES']
bs.to_excel('d:/RIV/SP500_noa_2016.xlsx',sheet_name='sheet10086')#write excel
result_2016=bs.T

b=pd.DataFrame({})
i=0
while i<len(statement_2015.Fields):
    b[statement_2015.Fields[i]]=statement_2015.Data[i]
    i=i+1

c=b.T
c.columns = statement_2015.Codes
bs=c.T

bs.fillna(0,inplace=True)#transfer NaN to 0
WGSD_CCE_OPER=bs.WGSD_CCE*0.01#separate cash to operating & financing asset
WGSD_CCE_FINC=bs.WGSD_CCE*0.99
WGSD_INVEST_TRADING_FINC=bs.WGSD_INVEST_TRADING
WGSD_INVEST_ST_OTH_FINC=bs.WGSD_INVEST_ST_OTH
WGSD_RECEIV_NET_OPER=bs.WGSD_RECEIV_NET
WGSD_INVENTORIES_OPER=bs.WGSD_INVENTORIES
WGSD_ASSETS_CURR_OTH_OPER=bs.WGSD_ASSETS_CURR_OTH
WGSD_PPE_NET_OPER=bs.WGSD_PPE_NET
WGSD_INVEST_EQ_FINC=bs.WGSD_INVEST_EQ
WGSD_INVEST_HTM_FINC=bs.WGSD_INVEST_HTM
WGSD_INVEST_AFS_FINC=bs.WGSD_INVEST_AFS
WGSD_INVEST_LT_OTH_FINC=bs.WGSD_INVEST_LT_OTH
WGSD_GW_INTANG_OPER=bs.WGSD_GW_INTANG_
WGSD_LAND_USE_RIGHTS_OPER=bs.WGSD_LAND_USE_RIGHTS
WGSD_ASSETS_LT_OTH_OPER=bs.WGSD_ASSETS_LT_OTH
WGSD_LEND_IB_FINC=bs.WGSD_LEND_IB
WGSD_SEC_COLLA_FINC=bs.WGSD_SEC_COLLA
WGSD_LOANS_NET_FINC=bs.WGSD_LOANS_NET
WGSD_LOANS_HFS_FINC=bs.WGSD_LOANS_HFS
WGSD_ASSETS_OTH_OPER=bs.WGSD_ASSETS_OTH
WGSD_INVEST_OTH_FINC=bs.WGSD_INVEST_OTH
WGSD_RECEIV_INSUR_OPER=bs.WGSD_RECEIV_INSUR
WGSD_DEF_PLCY_ACQ_COSTS_OPER=bs.WGSD_DEF_PLCY_ACQ_COSTS
WGSD_RECEIV_REINSUR_OPER=bs.WGSD_RECEIV_REINSUR
WGSD_RECEIV_ST_OTH_OPER=bs.WGSD_RECEIV_ST_OTH
WGSD_LOANS_MTG_NET_OPER=bs.WGSD_LOANS_MTG_NET
WGSD_REAL_ESTATE_NET_OPER=bs.WGSD_REAL_ESTATE_NET
WGSD_PPE_NET_OTH_OPER=bs.WGSD_PPE_NET_OTH

#add column to excel
#assets
bs['WGSD_CCE_OPER']=WGSD_CCE_OPER
bs['WGSD_CCE_FINC']=WGSD_CCE_FINC
bs['WGSD_INVEST_TRADING_FINC']=WGSD_INVEST_TRADING_FINC
bs['WGSD_INVEST_ST_OTH_FINC']=WGSD_INVEST_ST_OTH_FINC
bs['WGSD_RECEIV_NET_OPER']=WGSD_RECEIV_NET_OPER
bs['WGSD_INVENTORIES_OPER']=WGSD_INVENTORIES_OPER
bs['WGSD_ASSETS_CURR_OTH_OPER']=WGSD_ASSETS_CURR_OTH_OPER
bs['WGSD_PPE_NET_OPER']=WGSD_PPE_NET_OPER
bs['WGSD_INVEST_EQ_FINC']=WGSD_INVEST_EQ_FINC
bs['WGSD_INVEST_HTM_FINC']=WGSD_INVEST_HTM_FINC
bs['WGSD_INVEST_AFS_FINC']=WGSD_INVEST_AFS_FINC
bs['WGSD_INVEST_LT_OTH_FINC']=WGSD_INVEST_LT_OTH_FINC
bs['WGSD_GW_INTANG_OPER']=WGSD_GW_INTANG_OPER
bs['WGSD_LAND_USE_RIGHTS_OPER']=WGSD_LAND_USE_RIGHTS_OPER
bs['WGSD_ASSETS_LT_OTH_OPER']=WGSD_ASSETS_LT_OTH_OPER
bs['WGSD_LEND_IB_FINC']=WGSD_LEND_IB_FINC
bs['WGSD_SEC_COLLA_FINC']=WGSD_SEC_COLLA_FINC
bs['WGSD_LOANS_NET_FINC']=WGSD_LOANS_NET_FINC
bs['WGSD_LOANS_HFS_FINC']=WGSD_LOANS_HFS_FINC
bs['WGSD_ASSETS_OTH_OPER']=WGSD_ASSETS_OTH_OPER
bs['WGSD_INVEST_OTH_FINC']=WGSD_INVEST_OTH_FINC
bs['WGSD_RECEIV_INSUR_OPER']=WGSD_RECEIV_INSUR_OPER
bs['WGSD_DEF_PLCY_ACQ_COSTS_OPER']=WGSD_DEF_PLCY_ACQ_COSTS_OPER
bs['WGSD_RECEIV_REINSUR_OPER']=WGSD_RECEIV_REINSUR_OPER
bs['WGSD_RECEIV_ST_OTH_OPER']=WGSD_RECEIV_ST_OTH_OPER
bs['WGSD_LOANS_MTG_NET_OPER']=WGSD_LOANS_MTG_NET_OPER
bs['WGSD_REAL_ESTATE_NET_OPER']=WGSD_REAL_ESTATE_NET_OPER
bs['WGSD_PPE_NET_OTH_OPER']=WGSD_PPE_NET_OTH_OPER
#liabs&prefered_share
WGSD_PAY_ACCT_OPER=bs.WGSD_PAY_ACCT
WGSD_PAY_TAX_OPER=bs.WGSD_PAY_TAX
WGSD_LIABS_TRADING_FINC=bs.WGSD_LIABS_TRADING
WGSD_DEBT_ST_OPER=bs.WGSD_DEBT_ST
WGSD_LIABS_CURR_OTH_OPER=bs.WGSD_LIABS_CURR_OTH
WGSD_DEBT_LT_FINC=bs.WGSD_DEBT_LT
WGSD_LIABS_LT_OTH_FINC=bs.WGSD_LIABS_LT_OTH
WGSD_DEPOSITS_OPERXXX=bs.WGSD_DEPOSITS
WGSD_BORROW_IB_OPERXXX=bs.WGSD_BORROW_IB
WGSD_FIN_COLLA_FINC=bs.WGSD_FIN_COLLA
WGSD_LIABS_OTH_FINC=bs.WGSD_LIABS_OTH
WGSD_LIABS_INSUR_CONTRACT_OPER=bs.WGSD_LIABS_INSUR_CONTRACT
WGSD_PAY_REINSUR_OPER=bs.WGSD_PAY_REINSUR
WGSD_LIABS_INVEST_CONTRACT_OPER=bs.WGSD_LIABS_INVEST_CONTRACT
WGSD_PFD_STK_FINC=bs.WGSD_PFD_STK
bs['WGSD_PAY_ACCT_OPER']=WGSD_PAY_ACCT_OPER
bs['WGSD_PAY_TAX_OPER']=WGSD_PAY_TAX_OPER
bs['WGSD_LIABS_TRADING_FINC']=WGSD_LIABS_TRADING_FINC
bs['WGSD_DEBT_ST_OPER']=WGSD_DEBT_ST_OPER
bs['WGSD_LIABS_CURR_OTH_OPER']=WGSD_LIABS_CURR_OTH_OPER
bs['WGSD_DEBT_LT_FINC']=WGSD_DEBT_LT_FINC
bs['WGSD_LIABS_LT_OTH_FINC']=WGSD_LIABS_LT_OTH_FINC
bs['WGSD_DEPOSITS_OPERXXX']=WGSD_DEPOSITS_OPERXXX
bs['WGSD_BORROW_IB_OPERXXX']=WGSD_BORROW_IB_OPERXXX
bs['WGSD_FIN_COLLA_FINC']=WGSD_FIN_COLLA_FINC
bs['WGSD_LIABS_OTH_FINC']=WGSD_LIABS_OTH_FINC
bs['WGSD_LIABS_INSUR_CONTRACT_OPER']=WGSD_LIABS_INSUR_CONTRACT_OPER
bs['WGSD_PAY_REINSUR_OPER']=WGSD_PAY_REINSUR_OPER
bs['WGSD_LIABS_INVEST_CONTRACT_OPER']=WGSD_LIABS_INVEST_CONTRACT_OPER
bs['WGSD_PFD_STK_FINC']=WGSD_PFD_STK_FINC
##calculate NOA & NFA
#OA
WGSD_ASSET_TOT_OPER=bs.WGSD_CCE_OPER+bs.WGSD_RECEIV_NET_OPER+bs.WGSD_INVENTORIES_OPER+bs.WGSD_ASSETS_CURR_OTH_OPER\
+bs.WGSD_PPE_NET_OPER+bs.WGSD_GW_INTANG_OPER+bs.WGSD_LAND_USE_RIGHTS_OPER\
+bs.WGSD_ASSETS_LT_OTH_OPER+bs.WGSD_ASSETS_OTH_OPER+bs.WGSD_RECEIV_INSUR_OPER\
+bs.WGSD_DEF_PLCY_ACQ_COSTS_OPER+bs.WGSD_RECEIV_REINSUR_OPER\
+bs.WGSD_RECEIV_ST_OTH_OPER+bs.WGSD_LOANS_MTG_NET_OPER+bs.WGSD_REAL_ESTATE_NET_OPER+bs.WGSD_PPE_NET_OTH_OPER
#FA
WGSD_ASSET_TOT_FINC=bs.WGSD_CCE_FINC+bs.WGSD_INVEST_TRADING_FINC+bs.WGSD_INVEST_ST_OTH_FINC\
+bs.WGSD_INVEST_EQ_FINC+bs.WGSD_INVEST_HTM_FINC+bs.WGSD_INVEST_AFS_FINC\
+bs.WGSD_INVEST_LT_OTH_FINC+bs.WGSD_LEND_IB_FINC+bs.WGSD_SEC_COLLA_FINC\
+bs.WGSD_LOANS_NET_FINC+bs.WGSD_LOANS_HFS_FINC+bs.WGSD_INVEST_OTH_FINC
#LA
WGSD_LIABS_TOT_OPER=bs.WGSD_PAY_ACCT_OPER+bs.WGSD_PAY_TAX_OPER+bs.WGSD_DEBT_ST_OPER\
+bs.WGSD_LIABS_CURR_OTH_OPER+bs.WGSD_DEPOSITS_OPERXXX+bs.WGSD_BORROW_IB_OPERXXX\
+bs.WGSD_LIABS_INSUR_CONTRACT_OPER+bs.WGSD_PAY_REINSUR_OPER+bs.WGSD_LIABS_INVEST_CONTRACT_OPER
WGSD_LIABS_TOT_FINC=bs.WGSD_LIABS_TRADING_FINC+bs.WGSD_DEBT_LT_FINC+bs.WGSD_LIABS_LT_OTH_FINC\
+bs.WGSD_FIN_COLLA_FINC+bs.WGSD_LIABS_OTH_FINC+bs.WGSD_PFD_STK_FINC
bs['WGSD_ASSET_TOT_OPER']=WGSD_ASSET_TOT_OPER
bs['WGSD_ASSET_TOT_FINC']=WGSD_ASSET_TOT_FINC
bs['WGSD_LIABS_TOT_OPER']=WGSD_LIABS_TOT_OPER
bs['WGSD_LIABS_TOT_FINC']=WGSD_LIABS_TOT_FINC
#NOA & NFA
WGSD_NOA_ALPHA=bs.WGSD_ASSET_TOT_OPER-bs.WGSD_LIABS_TOT_OPER
WGSD_NFA_ALPHA=bs.WGSD_ASSET_TOT_FINC-bs.WGSD_LIABS_TOT_FINC
bs['WGSD_NOA_ALPHA']=WGSD_NOA_ALPHA
bs['WGSD_NFA_ALPHA']=WGSD_NFA_ALPHA
bs['WGSD_OTHER_NOA']=bs.WGSD_NOA_ALPHA-bs.WGSD_PPE_NET_OPER-bs.WGSD_INVENTORIES_OPER-bs.WGSD_RECEIV_NET_OPER
bs['WGSD_NET_INC_EXP']=bs['WGSD_INT_EXP']-bs['WGSD_INT_INC']
bs['WGSD_TAX_BENEFIT']=bs['WGSD_NET_INC_EXP']*0.38 # assume the corporate tax rate in USA is 38%
bs['WGSD_OPERATING_TAX']=bs['WGSD_TAX_BENEFIT']+bs['WGSD_INC_TAX']
bs['WGSD_INVENTORY_TURNOVER']=bs['WGSD_OPER_COST']/bs['WGSD_INVENTORIES']
bs['WGSD_PPE_TURNOVER']=bs['WGSD_SALES']/bs['WGSD_PPE_NET']
bs['WGSD_RECEIVABLES_TURNOVER']=bs['WGSD_SALES']/bs['WGSD_RECEIV_NET']
bs['WGSD_GROSS_MARGIN']=(bs['WGSD_SALES']-bs['WGSD_OPER_COST'])/bs['WGSD_SALES']
bs['WGSD_SGA_EXPENSE_RATIO']=(bs['WGSD_OPER_EXP']/bs['WGSD_SALES'])
bs['WGSD_OTHER_NOA2SALES']=bs['WGSD_OTHER_NOA']/bs['WGSD_SALES']
bs.to_excel('d:/RIV/SP500_noa_2015.xlsx',sheet_name='sheet10086')#write excel
result_2015=bs.T

b=pd.DataFrame({})
i=0
while i<len(statement_2014.Fields):
    b[statement_2014.Fields[i]]=statement_2014.Data[i]
    i=i+1

c=b.T
c.columns = statement_2014.Codes
bs=c.T

bs.fillna(0,inplace=True)#transfer NaN to 0
WGSD_CCE_OPER=bs.WGSD_CCE*0.01#separate cash to operating & financing asset
WGSD_CCE_FINC=bs.WGSD_CCE*0.99
WGSD_INVEST_TRADING_FINC=bs.WGSD_INVEST_TRADING
WGSD_INVEST_ST_OTH_FINC=bs.WGSD_INVEST_ST_OTH
WGSD_RECEIV_NET_OPER=bs.WGSD_RECEIV_NET
WGSD_INVENTORIES_OPER=bs.WGSD_INVENTORIES
WGSD_ASSETS_CURR_OTH_OPER=bs.WGSD_ASSETS_CURR_OTH
WGSD_PPE_NET_OPER=bs.WGSD_PPE_NET
WGSD_INVEST_EQ_FINC=bs.WGSD_INVEST_EQ
WGSD_INVEST_HTM_FINC=bs.WGSD_INVEST_HTM
WGSD_INVEST_AFS_FINC=bs.WGSD_INVEST_AFS
WGSD_INVEST_LT_OTH_FINC=bs.WGSD_INVEST_LT_OTH
WGSD_GW_INTANG_OPER=bs.WGSD_GW_INTANG_
WGSD_LAND_USE_RIGHTS_OPER=bs.WGSD_LAND_USE_RIGHTS
WGSD_ASSETS_LT_OTH_OPER=bs.WGSD_ASSETS_LT_OTH
WGSD_LEND_IB_FINC=bs.WGSD_LEND_IB
WGSD_SEC_COLLA_FINC=bs.WGSD_SEC_COLLA
WGSD_LOANS_NET_FINC=bs.WGSD_LOANS_NET
WGSD_LOANS_HFS_FINC=bs.WGSD_LOANS_HFS
WGSD_ASSETS_OTH_OPER=bs.WGSD_ASSETS_OTH
WGSD_INVEST_OTH_FINC=bs.WGSD_INVEST_OTH
WGSD_RECEIV_INSUR_OPER=bs.WGSD_RECEIV_INSUR
WGSD_DEF_PLCY_ACQ_COSTS_OPER=bs.WGSD_DEF_PLCY_ACQ_COSTS
WGSD_RECEIV_REINSUR_OPER=bs.WGSD_RECEIV_REINSUR
WGSD_RECEIV_ST_OTH_OPER=bs.WGSD_RECEIV_ST_OTH
WGSD_LOANS_MTG_NET_OPER=bs.WGSD_LOANS_MTG_NET
WGSD_REAL_ESTATE_NET_OPER=bs.WGSD_REAL_ESTATE_NET
WGSD_PPE_NET_OTH_OPER=bs.WGSD_PPE_NET_OTH

#add column to excel
#assets
bs['WGSD_CCE_OPER']=WGSD_CCE_OPER
bs['WGSD_CCE_FINC']=WGSD_CCE_FINC
bs['WGSD_INVEST_TRADING_FINC']=WGSD_INVEST_TRADING_FINC
bs['WGSD_INVEST_ST_OTH_FINC']=WGSD_INVEST_ST_OTH_FINC
bs['WGSD_RECEIV_NET_OPER']=WGSD_RECEIV_NET_OPER
bs['WGSD_INVENTORIES_OPER']=WGSD_INVENTORIES_OPER
bs['WGSD_ASSETS_CURR_OTH_OPER']=WGSD_ASSETS_CURR_OTH_OPER
bs['WGSD_PPE_NET_OPER']=WGSD_PPE_NET_OPER
bs['WGSD_INVEST_EQ_FINC']=WGSD_INVEST_EQ_FINC
bs['WGSD_INVEST_HTM_FINC']=WGSD_INVEST_HTM_FINC
bs['WGSD_INVEST_AFS_FINC']=WGSD_INVEST_AFS_FINC
bs['WGSD_INVEST_LT_OTH_FINC']=WGSD_INVEST_LT_OTH_FINC
bs['WGSD_GW_INTANG_OPER']=WGSD_GW_INTANG_OPER
bs['WGSD_LAND_USE_RIGHTS_OPER']=WGSD_LAND_USE_RIGHTS_OPER
bs['WGSD_ASSETS_LT_OTH_OPER']=WGSD_ASSETS_LT_OTH_OPER
bs['WGSD_LEND_IB_FINC']=WGSD_LEND_IB_FINC
bs['WGSD_SEC_COLLA_FINC']=WGSD_SEC_COLLA_FINC
bs['WGSD_LOANS_NET_FINC']=WGSD_LOANS_NET_FINC
bs['WGSD_LOANS_HFS_FINC']=WGSD_LOANS_HFS_FINC
bs['WGSD_ASSETS_OTH_OPER']=WGSD_ASSETS_OTH_OPER
bs['WGSD_INVEST_OTH_FINC']=WGSD_INVEST_OTH_FINC
bs['WGSD_RECEIV_INSUR_OPER']=WGSD_RECEIV_INSUR_OPER
bs['WGSD_DEF_PLCY_ACQ_COSTS_OPER']=WGSD_DEF_PLCY_ACQ_COSTS_OPER
bs['WGSD_RECEIV_REINSUR_OPER']=WGSD_RECEIV_REINSUR_OPER
bs['WGSD_RECEIV_ST_OTH_OPER']=WGSD_RECEIV_ST_OTH_OPER
bs['WGSD_LOANS_MTG_NET_OPER']=WGSD_LOANS_MTG_NET_OPER
bs['WGSD_REAL_ESTATE_NET_OPER']=WGSD_REAL_ESTATE_NET_OPER
bs['WGSD_PPE_NET_OTH_OPER']=WGSD_PPE_NET_OTH_OPER
#liabs&prefered_share
WGSD_PAY_ACCT_OPER=bs.WGSD_PAY_ACCT
WGSD_PAY_TAX_OPER=bs.WGSD_PAY_TAX
WGSD_LIABS_TRADING_FINC=bs.WGSD_LIABS_TRADING
WGSD_DEBT_ST_OPER=bs.WGSD_DEBT_ST
WGSD_LIABS_CURR_OTH_OPER=bs.WGSD_LIABS_CURR_OTH
WGSD_DEBT_LT_FINC=bs.WGSD_DEBT_LT
WGSD_LIABS_LT_OTH_FINC=bs.WGSD_LIABS_LT_OTH
WGSD_DEPOSITS_OPERXXX=bs.WGSD_DEPOSITS
WGSD_BORROW_IB_OPERXXX=bs.WGSD_BORROW_IB
WGSD_FIN_COLLA_FINC=bs.WGSD_FIN_COLLA
WGSD_LIABS_OTH_FINC=bs.WGSD_LIABS_OTH
WGSD_LIABS_INSUR_CONTRACT_OPER=bs.WGSD_LIABS_INSUR_CONTRACT
WGSD_PAY_REINSUR_OPER=bs.WGSD_PAY_REINSUR
WGSD_LIABS_INVEST_CONTRACT_OPER=bs.WGSD_LIABS_INVEST_CONTRACT
WGSD_PFD_STK_FINC=bs.WGSD_PFD_STK
bs['WGSD_PAY_ACCT_OPER']=WGSD_PAY_ACCT_OPER
bs['WGSD_PAY_TAX_OPER']=WGSD_PAY_TAX_OPER
bs['WGSD_LIABS_TRADING_FINC']=WGSD_LIABS_TRADING_FINC
bs['WGSD_DEBT_ST_OPER']=WGSD_DEBT_ST_OPER
bs['WGSD_LIABS_CURR_OTH_OPER']=WGSD_LIABS_CURR_OTH_OPER
bs['WGSD_DEBT_LT_FINC']=WGSD_DEBT_LT_FINC
bs['WGSD_LIABS_LT_OTH_FINC']=WGSD_LIABS_LT_OTH_FINC
bs['WGSD_DEPOSITS_OPERXXX']=WGSD_DEPOSITS_OPERXXX
bs['WGSD_BORROW_IB_OPERXXX']=WGSD_BORROW_IB_OPERXXX
bs['WGSD_FIN_COLLA_FINC']=WGSD_FIN_COLLA_FINC
bs['WGSD_LIABS_OTH_FINC']=WGSD_LIABS_OTH_FINC
bs['WGSD_LIABS_INSUR_CONTRACT_OPER']=WGSD_LIABS_INSUR_CONTRACT_OPER
bs['WGSD_PAY_REINSUR_OPER']=WGSD_PAY_REINSUR_OPER
bs['WGSD_LIABS_INVEST_CONTRACT_OPER']=WGSD_LIABS_INVEST_CONTRACT_OPER
bs['WGSD_PFD_STK_FINC']=WGSD_PFD_STK_FINC

##calculate NOA & NFA
#OA
WGSD_ASSET_TOT_OPER=bs.WGSD_CCE_OPER+bs.WGSD_RECEIV_NET_OPER+bs.WGSD_INVENTORIES_OPER+bs.WGSD_ASSETS_CURR_OTH_OPER\
+bs.WGSD_PPE_NET_OPER+bs.WGSD_GW_INTANG_OPER+bs.WGSD_LAND_USE_RIGHTS_OPER\
+bs.WGSD_ASSETS_LT_OTH_OPER+bs.WGSD_ASSETS_OTH_OPER+bs.WGSD_RECEIV_INSUR_OPER\
+bs.WGSD_DEF_PLCY_ACQ_COSTS_OPER+bs.WGSD_RECEIV_REINSUR_OPER\
+bs.WGSD_RECEIV_ST_OTH_OPER+bs.WGSD_LOANS_MTG_NET_OPER+bs.WGSD_REAL_ESTATE_NET_OPER+bs.WGSD_PPE_NET_OTH_OPER
#FA
WGSD_ASSET_TOT_FINC=bs.WGSD_CCE_FINC+bs.WGSD_INVEST_TRADING_FINC+bs.WGSD_INVEST_ST_OTH_FINC\
+bs.WGSD_INVEST_EQ_FINC+bs.WGSD_INVEST_HTM_FINC+bs.WGSD_INVEST_AFS_FINC\
+bs.WGSD_INVEST_LT_OTH_FINC+bs.WGSD_LEND_IB_FINC+bs.WGSD_SEC_COLLA_FINC\
+bs.WGSD_LOANS_NET_FINC+bs.WGSD_LOANS_HFS_FINC+bs.WGSD_INVEST_OTH_FINC
#LA
WGSD_LIABS_TOT_OPER=bs.WGSD_PAY_ACCT_OPER+bs.WGSD_PAY_TAX_OPER+bs.WGSD_DEBT_ST_OPER\
+bs.WGSD_LIABS_CURR_OTH_OPER+bs.WGSD_DEPOSITS_OPERXXX+bs.WGSD_BORROW_IB_OPERXXX\
+bs.WGSD_LIABS_INSUR_CONTRACT_OPER+bs.WGSD_PAY_REINSUR_OPER+bs.WGSD_LIABS_INVEST_CONTRACT_OPER
WGSD_LIABS_TOT_FINC=bs.WGSD_LIABS_TRADING_FINC+bs.WGSD_DEBT_LT_FINC+bs.WGSD_LIABS_LT_OTH_FINC\
+bs.WGSD_FIN_COLLA_FINC+bs.WGSD_LIABS_OTH_FINC+bs.WGSD_PFD_STK_FINC
bs['WGSD_ASSET_TOT_OPER']=WGSD_ASSET_TOT_OPER
bs['WGSD_ASSET_TOT_FINC']=WGSD_ASSET_TOT_FINC
bs['WGSD_LIABS_TOT_OPER']=WGSD_LIABS_TOT_OPER
bs['WGSD_LIABS_TOT_FINC']=WGSD_LIABS_TOT_FINC
#NOA & NFA
WGSD_NOA_ALPHA=bs.WGSD_ASSET_TOT_OPER-bs.WGSD_LIABS_TOT_OPER
WGSD_NFA_ALPHA=bs.WGSD_ASSET_TOT_FINC-bs.WGSD_LIABS_TOT_FINC
bs['WGSD_NOA_ALPHA']=WGSD_NOA_ALPHA
bs['WGSD_NFA_ALPHA']=WGSD_NFA_ALPHA
bs['WGSD_OTHER_NOA']=bs.WGSD_NOA_ALPHA-bs.WGSD_PPE_NET_OPER-bs.WGSD_INVENTORIES_OPER-bs.WGSD_RECEIV_NET_OPER
bs['WGSD_NET_INC_EXP']=bs['WGSD_INT_EXP']-bs['WGSD_INT_INC']
bs['WGSD_TAX_BENEFIT']=bs['WGSD_NET_INC_EXP']*0.38 # assume the corporate tax rate in USA is 38%
bs['WGSD_OPERATING_TAX']=bs['WGSD_TAX_BENEFIT']+bs['WGSD_INC_TAX']
bs['WGSD_INVENTORY_TURNOVER']=bs['WGSD_OPER_COST']/bs['WGSD_INVENTORIES']
bs['WGSD_PPE_TURNOVER']=bs['WGSD_SALES']/bs['WGSD_PPE_NET']
bs['WGSD_RECEIVABLES_TURNOVER']=bs['WGSD_SALES']/bs['WGSD_RECEIV_NET']
bs['WGSD_GROSS_MARGIN']=(bs['WGSD_SALES']-bs['WGSD_OPER_COST'])/bs['WGSD_SALES']
bs['WGSD_SGA_EXPENSE_RATIO']=(bs['WGSD_OPER_EXP']/bs['WGSD_SALES'])
bs['WGSD_OTHER_NOA2SALES']=bs['WGSD_OTHER_NOA']/bs['WGSD_SALES']
bs.to_excel('d:/RIV/SP500_noa_2014.xlsx',sheet_name='sheet10086')#write excel
result_2014=bs.T

b=pd.DataFrame({})
i=0
while i<len(statement_2013.Fields):
    b[statement_2013.Fields[i]]=statement_2013.Data[i]
    i=i+1

c=b.T
c.columns = statement_2013.Codes
bs=c.T

bs.fillna(0,inplace=True)#transfer NaN to 0
WGSD_CCE_OPER=bs.WGSD_CCE*0.01#separate cash to operating & financing asset
WGSD_CCE_FINC=bs.WGSD_CCE*0.99
WGSD_INVEST_TRADING_FINC=bs.WGSD_INVEST_TRADING
WGSD_INVEST_ST_OTH_FINC=bs.WGSD_INVEST_ST_OTH
WGSD_RECEIV_NET_OPER=bs.WGSD_RECEIV_NET
WGSD_INVENTORIES_OPER=bs.WGSD_INVENTORIES
WGSD_ASSETS_CURR_OTH_OPER=bs.WGSD_ASSETS_CURR_OTH
WGSD_PPE_NET_OPER=bs.WGSD_PPE_NET
WGSD_INVEST_EQ_FINC=bs.WGSD_INVEST_EQ
WGSD_INVEST_HTM_FINC=bs.WGSD_INVEST_HTM
WGSD_INVEST_AFS_FINC=bs.WGSD_INVEST_AFS
WGSD_INVEST_LT_OTH_FINC=bs.WGSD_INVEST_LT_OTH
WGSD_GW_INTANG_OPER=bs.WGSD_GW_INTANG_
WGSD_LAND_USE_RIGHTS_OPER=bs.WGSD_LAND_USE_RIGHTS
WGSD_ASSETS_LT_OTH_OPER=bs.WGSD_ASSETS_LT_OTH
WGSD_LEND_IB_FINC=bs.WGSD_LEND_IB
WGSD_SEC_COLLA_FINC=bs.WGSD_SEC_COLLA
WGSD_LOANS_NET_FINC=bs.WGSD_LOANS_NET
WGSD_LOANS_HFS_FINC=bs.WGSD_LOANS_HFS
WGSD_ASSETS_OTH_OPER=bs.WGSD_ASSETS_OTH
WGSD_INVEST_OTH_FINC=bs.WGSD_INVEST_OTH
WGSD_RECEIV_INSUR_OPER=bs.WGSD_RECEIV_INSUR
WGSD_DEF_PLCY_ACQ_COSTS_OPER=bs.WGSD_DEF_PLCY_ACQ_COSTS
WGSD_RECEIV_REINSUR_OPER=bs.WGSD_RECEIV_REINSUR
WGSD_RECEIV_ST_OTH_OPER=bs.WGSD_RECEIV_ST_OTH
WGSD_LOANS_MTG_NET_OPER=bs.WGSD_LOANS_MTG_NET
WGSD_REAL_ESTATE_NET_OPER=bs.WGSD_REAL_ESTATE_NET
WGSD_PPE_NET_OTH_OPER=bs.WGSD_PPE_NET_OTH

#add column to excel
#assets
bs['WGSD_CCE_OPER']=WGSD_CCE_OPER
bs['WGSD_CCE_FINC']=WGSD_CCE_FINC
bs['WGSD_INVEST_TRADING_FINC']=WGSD_INVEST_TRADING_FINC
bs['WGSD_INVEST_ST_OTH_FINC']=WGSD_INVEST_ST_OTH_FINC
bs['WGSD_RECEIV_NET_OPER']=WGSD_RECEIV_NET_OPER
bs['WGSD_INVENTORIES_OPER']=WGSD_INVENTORIES_OPER
bs['WGSD_ASSETS_CURR_OTH_OPER']=WGSD_ASSETS_CURR_OTH_OPER
bs['WGSD_PPE_NET_OPER']=WGSD_PPE_NET_OPER
bs['WGSD_INVEST_EQ_FINC']=WGSD_INVEST_EQ_FINC
bs['WGSD_INVEST_HTM_FINC']=WGSD_INVEST_HTM_FINC
bs['WGSD_INVEST_AFS_FINC']=WGSD_INVEST_AFS_FINC
bs['WGSD_INVEST_LT_OTH_FINC']=WGSD_INVEST_LT_OTH_FINC
bs['WGSD_GW_INTANG_OPER']=WGSD_GW_INTANG_OPER
bs['WGSD_LAND_USE_RIGHTS_OPER']=WGSD_LAND_USE_RIGHTS_OPER
bs['WGSD_ASSETS_LT_OTH_OPER']=WGSD_ASSETS_LT_OTH_OPER
bs['WGSD_LEND_IB_FINC']=WGSD_LEND_IB_FINC
bs['WGSD_SEC_COLLA_FINC']=WGSD_SEC_COLLA_FINC
bs['WGSD_LOANS_NET_FINC']=WGSD_LOANS_NET_FINC
bs['WGSD_LOANS_HFS_FINC']=WGSD_LOANS_HFS_FINC
bs['WGSD_ASSETS_OTH_OPER']=WGSD_ASSETS_OTH_OPER
bs['WGSD_INVEST_OTH_FINC']=WGSD_INVEST_OTH_FINC
bs['WGSD_RECEIV_INSUR_OPER']=WGSD_RECEIV_INSUR_OPER
bs['WGSD_DEF_PLCY_ACQ_COSTS_OPER']=WGSD_DEF_PLCY_ACQ_COSTS_OPER
bs['WGSD_RECEIV_REINSUR_OPER']=WGSD_RECEIV_REINSUR_OPER
bs['WGSD_RECEIV_ST_OTH_OPER']=WGSD_RECEIV_ST_OTH_OPER
bs['WGSD_LOANS_MTG_NET_OPER']=WGSD_LOANS_MTG_NET_OPER
bs['WGSD_REAL_ESTATE_NET_OPER']=WGSD_REAL_ESTATE_NET_OPER
bs['WGSD_PPE_NET_OTH_OPER']=WGSD_PPE_NET_OTH_OPER
#liabs&prefered_share
WGSD_PAY_ACCT_OPER=bs.WGSD_PAY_ACCT
WGSD_PAY_TAX_OPER=bs.WGSD_PAY_TAX
WGSD_LIABS_TRADING_FINC=bs.WGSD_LIABS_TRADING
WGSD_DEBT_ST_OPER=bs.WGSD_DEBT_ST
WGSD_LIABS_CURR_OTH_OPER=bs.WGSD_LIABS_CURR_OTH
WGSD_DEBT_LT_FINC=bs.WGSD_DEBT_LT
WGSD_LIABS_LT_OTH_FINC=bs.WGSD_LIABS_LT_OTH
WGSD_DEPOSITS_OPERXXX=bs.WGSD_DEPOSITS
WGSD_BORROW_IB_OPERXXX=bs.WGSD_BORROW_IB
WGSD_FIN_COLLA_FINC=bs.WGSD_FIN_COLLA
WGSD_LIABS_OTH_FINC=bs.WGSD_LIABS_OTH
WGSD_LIABS_INSUR_CONTRACT_OPER=bs.WGSD_LIABS_INSUR_CONTRACT
WGSD_PAY_REINSUR_OPER=bs.WGSD_PAY_REINSUR
WGSD_LIABS_INVEST_CONTRACT_OPER=bs.WGSD_LIABS_INVEST_CONTRACT
WGSD_PFD_STK_FINC=bs.WGSD_PFD_STK
bs['WGSD_PAY_ACCT_OPER']=WGSD_PAY_ACCT_OPER
bs['WGSD_PAY_TAX_OPER']=WGSD_PAY_TAX_OPER
bs['WGSD_LIABS_TRADING_FINC']=WGSD_LIABS_TRADING_FINC
bs['WGSD_DEBT_ST_OPER']=WGSD_DEBT_ST_OPER
bs['WGSD_LIABS_CURR_OTH_OPER']=WGSD_LIABS_CURR_OTH_OPER
bs['WGSD_DEBT_LT_FINC']=WGSD_DEBT_LT_FINC
bs['WGSD_LIABS_LT_OTH_FINC']=WGSD_LIABS_LT_OTH_FINC
bs['WGSD_DEPOSITS_OPERXXX']=WGSD_DEPOSITS_OPERXXX
bs['WGSD_BORROW_IB_OPERXXX']=WGSD_BORROW_IB_OPERXXX
bs['WGSD_FIN_COLLA_FINC']=WGSD_FIN_COLLA_FINC
bs['WGSD_LIABS_OTH_FINC']=WGSD_LIABS_OTH_FINC
bs['WGSD_LIABS_INSUR_CONTRACT_OPER']=WGSD_LIABS_INSUR_CONTRACT_OPER
bs['WGSD_PAY_REINSUR_OPER']=WGSD_PAY_REINSUR_OPER
bs['WGSD_LIABS_INVEST_CONTRACT_OPER']=WGSD_LIABS_INVEST_CONTRACT_OPER
bs['WGSD_PFD_STK_FINC']=WGSD_PFD_STK_FINC
##calculate NOA & NFA
#OA
WGSD_ASSET_TOT_OPER=bs.WGSD_CCE_OPER+bs.WGSD_RECEIV_NET_OPER+bs.WGSD_INVENTORIES_OPER+bs.WGSD_ASSETS_CURR_OTH_OPER\
+bs.WGSD_PPE_NET_OPER+bs.WGSD_GW_INTANG_OPER+bs.WGSD_LAND_USE_RIGHTS_OPER\
+bs.WGSD_ASSETS_LT_OTH_OPER+bs.WGSD_ASSETS_OTH_OPER+bs.WGSD_RECEIV_INSUR_OPER\
+bs.WGSD_DEF_PLCY_ACQ_COSTS_OPER+bs.WGSD_RECEIV_REINSUR_OPER\
+bs.WGSD_RECEIV_ST_OTH_OPER+bs.WGSD_LOANS_MTG_NET_OPER+bs.WGSD_REAL_ESTATE_NET_OPER+bs.WGSD_PPE_NET_OTH_OPER
#FA
WGSD_ASSET_TOT_FINC=bs.WGSD_CCE_FINC+bs.WGSD_INVEST_TRADING_FINC+bs.WGSD_INVEST_ST_OTH_FINC\
+bs.WGSD_INVEST_EQ_FINC+bs.WGSD_INVEST_HTM_FINC+bs.WGSD_INVEST_AFS_FINC\
+bs.WGSD_INVEST_LT_OTH_FINC+bs.WGSD_LEND_IB_FINC+bs.WGSD_SEC_COLLA_FINC\
+bs.WGSD_LOANS_NET_FINC+bs.WGSD_LOANS_HFS_FINC+bs.WGSD_INVEST_OTH_FINC
#LA
WGSD_LIABS_TOT_OPER=bs.WGSD_PAY_ACCT_OPER+bs.WGSD_PAY_TAX_OPER+bs.WGSD_DEBT_ST_OPER\
+bs.WGSD_LIABS_CURR_OTH_OPER+bs.WGSD_DEPOSITS_OPERXXX+bs.WGSD_BORROW_IB_OPERXXX\
+bs.WGSD_LIABS_INSUR_CONTRACT_OPER+bs.WGSD_PAY_REINSUR_OPER+bs.WGSD_LIABS_INVEST_CONTRACT_OPER
WGSD_LIABS_TOT_FINC=bs.WGSD_LIABS_TRADING_FINC+bs.WGSD_DEBT_LT_FINC+bs.WGSD_LIABS_LT_OTH_FINC\
+bs.WGSD_FIN_COLLA_FINC+bs.WGSD_LIABS_OTH_FINC+bs.WGSD_PFD_STK_FINC
bs['WGSD_ASSET_TOT_OPER']=WGSD_ASSET_TOT_OPER
bs['WGSD_ASSET_TOT_FINC']=WGSD_ASSET_TOT_FINC
bs['WGSD_LIABS_TOT_OPER']=WGSD_LIABS_TOT_OPER
bs['WGSD_LIABS_TOT_FINC']=WGSD_LIABS_TOT_FINC
#NOA & NFA
WGSD_NOA_ALPHA=bs.WGSD_ASSET_TOT_OPER-bs.WGSD_LIABS_TOT_OPER
WGSD_NFA_ALPHA=bs.WGSD_ASSET_TOT_FINC-bs.WGSD_LIABS_TOT_FINC
bs['WGSD_NOA_ALPHA']=WGSD_NOA_ALPHA
bs['WGSD_NFA_ALPHA']=WGSD_NFA_ALPHA
bs['WGSD_OTHER_NOA']=bs.WGSD_NOA_ALPHA-bs.WGSD_PPE_NET_OPER-bs.WGSD_INVENTORIES_OPER-bs.WGSD_RECEIV_NET_OPER
bs['WGSD_NET_INC_EXP']=bs['WGSD_INT_EXP']-bs['WGSD_INT_INC']
bs['WGSD_TAX_BENEFIT']=bs['WGSD_NET_INC_EXP']*0.38 # assume the corporate tax rate in USA is 38%
bs['WGSD_OPERATING_TAX']=bs['WGSD_TAX_BENEFIT']+bs['WGSD_INC_TAX']
bs['WGSD_INVENTORY_TURNOVER']=bs['WGSD_OPER_COST']/bs['WGSD_INVENTORIES']
bs['WGSD_PPE_TURNOVER']=bs['WGSD_SALES']/bs['WGSD_PPE_NET']
bs['WGSD_RECEIVABLES_TURNOVER']=bs['WGSD_SALES']/bs['WGSD_RECEIV_NET']
bs['WGSD_GROSS_MARGIN']=(bs['WGSD_SALES']-bs['WGSD_OPER_COST'])/bs['WGSD_SALES']
bs['WGSD_SGA_EXPENSE_RATIO']=(bs['WGSD_OPER_EXP']/bs['WGSD_SALES'])
bs['WGSD_OTHER_NOA2SALES']=bs['WGSD_OTHER_NOA']/bs['WGSD_SALES']
bs.to_excel('d:/RIV/SP500_noa_2013.xlsx',sheet_name='sheet10086')#write excel
result_2013=bs.T



##cost of operation
bs_re=pd.concat([result_2016,re],axis=0)#concat re and NOA
rd=0.05 #this is totally untrustworhty, need to be revised
bs_re_T=bs_re.T
bs_re_T.fillna(value=0)
bs_re_T['WGSD_STKHLDRS_EQ']
bs_re_T['r']=(bs_re_T['equity_return']*bs_re_T['WGSD_STKHLDRS_EQ']+(bs_re_T['WGSD_LIABS']-bs_re_T['WGSD_CCE'])*rd)/(bs_re_T['WGSD_STKHLDRS_EQ']+bs_re_T['WGSD_LIABS']-bs_re_T['WGSD_CCE'])
bs_re_T['r']
bs_re=bs_re_T.T
bs_re # r is the cost of operation
bs_re.to_excel('d:/RIV/cost_of_operation.xlsx')
result_2016=result_2016.T
result_2015=result_2015.T
result_2014=result_2014.T
result_2013=result_2013.T
result_2016['WGSD_REOI']=(result_2016['WGSD_RNOA']-AVERAGE3['COST_OF_OPERATIONS'])*result_2015['WGSD_NOA_ALPHA']
result_2016['WGSD_GROWTH_ON_REOI']=(result_2016['WGSD_REOI']-result_2015['WGSD_REOI'])/result_2015['WGSD_REOI']
diff_2014=(result_2014-result_2013)/result_2013
diff_2015=(result_2015-result_2014)/result_2014
diff_2016=(result_2016-result_2015)/result_2015
AVERAGE3=(result_2014+result_2016+result_2015)/3
AVERAGE3['COST_OF_OPERATIONS']=bs_re.T['r']
AVERAGE3['WGSD_SALES_INCREASE_RATE']=(diff_2014['WGSD_SALES']+diff_2015['WGSD_SALES']+diff_2016['WGSD_SALES'])/3
result_2017=pd.DataFrame({})
result_2017['WGSD_SALES']=result_2016['WGSD_SALES']*(AVERAGE3['WGSD_SALES_INCREASE_RATE']+1)
result_2017['WGSD_OPER_COST']=result_2016['WGSD_SALES']*(1-AVERAGE3['WGSD_GROSS_MARGIN'])
result_2017['WGSD_GROSS_MARGIN_AMOUNT']=result_2017['WGSD_SALES']-result_2017['WGSD_OPER_COST']
result_2017['WGSD_OPER_EXP']=result_2016['WGSD_SALES']*(AVERAGE3['WGSD_SGA_EXPENSE_RATIO'])
result_2017['WGSD_CORE_OPERATING_INCOME_BEFORE_TAX']=result_2017['WGSD_GROSS_MARGIN_AMOUNT']-result_2017['WGSD_OPER_EXP']
result_2017['WGSD_OPERATING_INCOME']=result_2017['WGSD_CORE_OPERATING_INCOME_BEFORE_TAX']*(1-0.38)
result_2017['WGSD_RECEIV_NET']=result_2017['WGSD_SALES']/AVERAGE3['WGSD_RECEIVABLES_TURNOVER']
result_2017['WGSD_INVENTORIES']=result_2017['WGSD_OPER_COST']/AVERAGE3['WGSD_INVENTORY_TURNOVER']
result_2017['WGSD_PPE_NET']=result_2017['WGSD_SALES']/AVERAGE3['WGSD_PPE_TURNOVER']
result_2017['WGSD_OTHER_NOA']=AVERAGE3['WGSD_OTHER_NOA2SALES']*result_2017['WGSD_SALES']
result_2017['WGSD_NOA_ALPHA']=result_2017['WGSD_RECEIV_NET']+result_2017['WGSD_INVENTORIES']+result_2017['WGSD_PPE_NET']+result_2017['WGSD_OTHER_NOA']
result_2017['WGSD_RNOA']=2*result_2017['WGSD_OPERATING_INCOME']/(result_2016['WGSD_NOA_ALPHA']+result_2017['WGSD_NOA_ALPHA'])
result_2017['WGSD_REOI']=(result_2017['WGSD_RNOA']-AVERAGE3['COST_OF_OPERATIONS'])*result_2016['WGSD_NOA_ALPHA']
result_2017['WGSD_GROWTH_ON_REOI']=(result_2017['WGSD_REOI']-result_2016['WGSD_REOI'])/result_2016['WGSD_REOI']
result_2017.to_excel('d:/RIV/predicted_2017.xlsx')

result_2018=pd.DataFrame({})
result_2018['WGSD_SALES']=result_2017['WGSD_SALES']*(AVERAGE3['WGSD_SALES_INCREASE_RATE']+1)
result_2018['WGSD_OPER_COST']=result_2017['WGSD_SALES']*(1-AVERAGE3['WGSD_GROSS_MARGIN'])
result_2018['WGSD_GROSS_MARGIN_AMOUNT']=result_2018['WGSD_SALES']-result_2018['WGSD_OPER_COST']
result_2018['WGSD_OPER_EXP']=result_2017['WGSD_SALES']*(AVERAGE3['WGSD_SGA_EXPENSE_RATIO'])
result_2018['WGSD_CORE_OPERATING_INCOME_BEFORE_TAX']=result_2018['WGSD_GROSS_MARGIN_AMOUNT']-result_2018['WGSD_OPER_EXP']
result_2018['WGSD_OPERATING_INCOME']=result_2018['WGSD_CORE_OPERATING_INCOME_BEFORE_TAX']*(1-0.38)
result_2018['WGSD_RECEIV_NET']=result_2018['WGSD_SALES']/AVERAGE3['WGSD_RECEIVABLES_TURNOVER']
result_2018['WGSD_INVENTORIES']=result_2018['WGSD_OPER_COST']/AVERAGE3['WGSD_INVENTORY_TURNOVER']
result_2018['WGSD_PPE_NET']=result_2018['WGSD_SALES']/AVERAGE3['WGSD_PPE_TURNOVER']
result_2018['WGSD_OTHER_NOA']=AVERAGE3['WGSD_OTHER_NOA2SALES']*result_2018['WGSD_SALES']
result_2018['WGSD_NOA_ALPHA']=result_2018['WGSD_RECEIV_NET']+result_2018['WGSD_INVENTORIES']+result_2018['WGSD_PPE_NET']+result_2018['WGSD_OTHER_NOA']
result_2018['WGSD_RNOA']=2*result_2018['WGSD_OPERATING_INCOME']/(result_2017['WGSD_NOA_ALPHA']+result_2018['WGSD_NOA_ALPHA'])
result_2018['WGSD_REOI']=(result_2018['WGSD_RNOA']-AVERAGE3['COST_OF_OPERATIONS'])*result_2017['WGSD_NOA_ALPHA']
result_2018['WGSD_GROWTH_ON_REOI']=(result_2018['WGSD_REOI']-result_2017['WGSD_REOI'])/result_2017['WGSD_REOI']
result_2018.to_excel('d:/RIV/predicted_2018.xlsx')

result_2019=pd.DataFrame({})
result_2019['WGSD_SALES']=result_2018['WGSD_SALES']*(AVERAGE3['WGSD_SALES_INCREASE_RATE']+1)
result_2019['WGSD_OPER_COST']=result_2018['WGSD_SALES']*(1-AVERAGE3['WGSD_GROSS_MARGIN'])
result_2019['WGSD_GROSS_MARGIN_AMOUNT']=result_2019['WGSD_SALES']-result_2019['WGSD_OPER_COST']
result_2019['WGSD_OPER_EXP']=result_2018['WGSD_SALES']*(AVERAGE3['WGSD_SGA_EXPENSE_RATIO'])
result_2019['WGSD_CORE_OPERATING_INCOME_BEFORE_TAX']=result_2019['WGSD_GROSS_MARGIN_AMOUNT']-result_2019['WGSD_OPER_EXP']
result_2019['WGSD_OPERATING_INCOME']=result_2019['WGSD_CORE_OPERATING_INCOME_BEFORE_TAX']*(1-0.38)
result_2019['WGSD_RECEIV_NET']=result_2019['WGSD_SALES']/AVERAGE3['WGSD_RECEIVABLES_TURNOVER']
result_2019['WGSD_INVENTORIES']=result_2019['WGSD_OPER_COST']/AVERAGE3['WGSD_INVENTORY_TURNOVER']
result_2019['WGSD_PPE_NET']=result_2019['WGSD_SALES']/AVERAGE3['WGSD_PPE_TURNOVER']
result_2019['WGSD_OTHER_NOA']=AVERAGE3['WGSD_OTHER_NOA2SALES']*result_2019['WGSD_SALES']
result_2019['WGSD_NOA_ALPHA']=result_2019['WGSD_RECEIV_NET']+result_2019['WGSD_INVENTORIES']+result_2019['WGSD_PPE_NET']+result_2019['WGSD_OTHER_NOA']
result_2019['WGSD_RNOA']=2*result_2019['WGSD_OPERATING_INCOME']/(result_2018['WGSD_NOA_ALPHA']+result_2019['WGSD_NOA_ALPHA'])
result_2019['WGSD_REOI']=(result_2019['WGSD_RNOA']-AVERAGE3['COST_OF_OPERATIONS'])*result_2018['WGSD_NOA_ALPHA']
result_2019['WGSD_GROWTH_ON_REOI']=(result_2019['WGSD_REOI']-result_2018['WGSD_REOI'])/result_2018['WGSD_REOI']
result_2019.to_excel('d:/RIV/predicted_2019.xlsx')

residual_value_model=pd.DataFrame({})
residual_value_model['TERMINAL_GROWTH']=(result_2016['WGSD_GROWTH_ON_REOI']+result_2017['WGSD_GROWTH_ON_REOI']+result_2018['WGSD_GROWTH_ON_REOI']+result_2019['WGSD_GROWTH_ON_REOI'])/4 # this should pay much more attention, since it is re;ated to macroeconomy & industries here the 2.5% increase of GDP is used
residual_value_model['WGSD_NEXT_REOI']=result_2019['WGSD_REOI']*(1+residual_value_model['TERMINAL_GROWTH'])
residual_value_model['WGSD_CONTINUE_VALUE']=residual_value_model['WGSD_NEXT_REOI']/(residual_value_model['TERMINAL_GROWTH']-AVERAGE3['COST_OF_OPERATIONS'])
residual_value_model['WGSD_CONTINUE_VALUE_PV']=residual_value_model['WGSD_CONTINUE_VALUE']/((1+residual_value_model['TERMINAL_GROWTH'])**3)
residual_value_model['TOTAL_PV_OF_REOI_TO_2016']=result_2019['WGSD_REOI']/((1+AVERAGE3['COST_OF_OPERATIONS'])**3)\
+result_2018['WGSD_REOI']/((1+residual_value_model['TERMINAL_GROWTH'])**2)\
+result_2017['WGSD_REOI']/((1+residual_value_model['TERMINAL_GROWTH']))
residual_value_model['NOA_AS_OF_2016']=result_2016['WGSD_NOA_ALPHA']
residual_value_model['VALUE_OF_OPERATIONS']=residual_value_model['WGSD_CONTINUE_VALUE_PV']\
+residual_value_model['TOTAL_PV_OF_REOI_TO_2016']\
+residual_value_model['NOA_AS_OF_2016']
residual_value_model['NFA']=result_2016['WGSD_NFA_ALPHA']
residual_value_model['VALUE_OF_COMMON_EQUITY']=residual_value_model['NFA']+residual_value_model['VALUE_OF_OPERATIONS']
residual_value_model['TOTAL_SHARES']=result_2016['TOTAL_SHARES']
residual_value_model['INTRINSIC_SHARE_PRICE']=residual_value_model['VALUE_OF_COMMON_EQUITY']/residual_value_model['TOTAL_SHARES']
residual_value_model.to_excel('d:/RIV/RV_MODEL.xlsx')

OUTPUT=pd.DataFrame({})
OUTPUT['INTRINSIC_SHARE_PRICE']=residual_value_model['INTRINSIC_SHARE_PRICE']
aaa=beta_b.T
ccc=aaa.iloc[:,-1]
OUTPUT['CLOSE_PRICE']=ccc
OUTPUT.to_excel('d:/RIV/Intrinsic_value&Closing_Price_of_20161230.xlsx')
# Out:
# betas of each companies:
#     SP500.SPI  A.N     AAL.O     AAP.N    AAPL.O    ABBV.N
# 0   1.164612  1.0  1.678283  1.207413  1.019282  0.819063
#
#  the equity return of each companies:
#     SP500.SPI       A.N    AAL.O     AAP.N    AAPL.O    ABBV.N
# 0   0.046529  0.042779  0.05823  0.047504  0.043218  0.038658
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-a20a22f30e8c> in <module>()
#      49
#      50 bs.fillna(0,inplace=True)#transfer NaN to 0
# ---> 51 WGSD_CCE_OPER=bs.WGSD_CCE*0.01#separate cash to operating & financing asset
#      52 WGSD_CCE_FINC=bs.WGSD_CCE*0.99
#      53 WGSD_INVEST_TRADING_FINC=bs.WGSD_INVEST_TRADING
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# ...

# %%
statement_2016
# Out:
# .ErrorCode=-40522017
# .Codes=[ErrorReport]
# .Fields=[OUTMESSAGE]
# .Times=[20180201 10:05:25]
# .Data=[[CWSSService: quota exceeded.]]
