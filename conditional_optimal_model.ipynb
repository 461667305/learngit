# %%
import xlrd   #generate data from Wind and choosing stocks.
import pandas as pd
import numpy as np
cc=pd.read_excel('cc.xlsx')
cc.fillna(0,inplace=True)
cc['WGSD_YOYEPS_DIFF']=cc.WGSD_YOYEPS_DILUTED-cc.AVG_WGSD_YOYEPS_DILUTED
cc['WGSD_YOYOP2_DIFF']=cc.WGSD_YOYOP2-cc.AVG_WGSD_YOYOP2
cc['WGSD_YOYNETPROFIT_DEDUCTED_DIFF']=cc.WGSD_YOYNETPROFIT_DEDUCTED-cc.AVG_WGSD_YOYNETPROFIT_DEDUCTED

for index,row in cc.iterrows():  
    if row['WGSD_YOYOP2']<15:
        cc.drop(index,axis=0,inplace=True)
    elif row['WGSD_YOYOP2']>45:
        cc.drop(index,axis=0,inplace=True)
    elif row['WGSD_YOYNETPROFIT_DEDUCTED']<15:
        cc.drop(index,axis=0,inplace=True)
    elif row['WGSD_YOYNETPROFIT_DEDUCTED']>45:
        cc.drop(index,axis=0,inplace=True)
    elif row['WGSD_YOYEPS_DILUTED']>45:
        cc.drop(index,axis=0,inplace=True)
    elif row['WGSD_YOYEPS_DILUTED']<15:
        cc.drop(index,axis=0,inplace=True)
    elif row['MKT_CAP']<1.0e+10:
        cc.drop(index,axis=0,inplace=True) 
    elif row['WGSD_YOYEPS_DIFF']<0:
        cc.drop(index,axis=0,inplace=True)
    elif row['WGSD_YOYOP2_DIFF']<0:
        cc.drop(index,axis=0,inplace=True)
    elif row['WGSD_YOYNETPROFIT_DEDUCTED_DIFF']<0:
        cc.drop(index,axis=0,inplace=True)
cc.index=cc['WindCodes']      
output=cc['WindCodes']
output
# Out:
# WindCodes
# 000042.SZ    000042.SZ
# 000423.SZ    000423.SZ
# 000596.SZ    000596.SZ
# 002032.SZ    002032.SZ
# 002544.SZ    002544.SZ
# 002668.SZ    002668.SZ
# 002773.SZ    002773.SZ
# 300003.SZ    300003.SZ
# 300122.SZ    300122.SZ
# 600054.SH    600054.SH
# 600271.SH    600271.SH
# 600376.SH    600376.SH
# 600522.SH    600522.SH
# 600562.SH    600562.SH
# 600998.SH    600998.SH
# 601900.SH    601900.SH
# 603866.SH    603866.SH
# Name: WindCodes, dtype: object

# %%
cc=pd.read_excel('cc.xlsx')
for i in cc['WGSD_YOYEPS_DILUTED']:
    if 15<i<45:

# %%
cc.fillna(0,inplace=True)
dd=cc[cc['WGSD_YOYE45]
ee=dd[dd['WGSD_YOYEPS_DILUTED']>15]
ee
# Out:
#       WindCodes  WGSD_YOYEPS_DILUTED  WGSD_YOYOP2  WGSD_YOYNETPROFIT_DEDUCTED  \
# 18    000022.SZ              26.3889     4.525260                     26.1488
# 26    000031.SZ              21.2121   -18.042690                     33.5143
# 34    000040.SZ              18.1818    41.226569                  31580.0964
# 35    000042.SZ              31.2804    42.294412                     39.6638
# 38    000046.SZ              29.6199    74.967821                     63.7801
# 62    000150.SZ              33.3333   897.944194                    110.4438
# 63    000151.SZ              18.6896   -27.794510                     17.2145
# 66    000156.SZ              21.2121    44.880180                     40.4642
# 72    000333.SZ              20.0803    -0.046210                      8.1683
# 78    000404.SZ              16.4126   -22.290475                      1.6069
# 88    000418.SZ              31.8182    21.054906                     69.1183
# ...

# %%
CC
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-b50ca9d003ff> in <module>()
# ----> 1 CC
#
# NameError: name 'CC' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NaN'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-3ddd75eb3192> in <module>()
# ----> 1 cc['NaN']
#
# ...
